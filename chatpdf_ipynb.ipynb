# %%
import sys, fitz
from tqdm import tqdm

import datetime
import os

# %%
def bbox_overlap(bbox1, bbox2):
    # bbox1 和 bbox2 分别为两个边界框的坐标 [x1, y1, x2, y2]
    x1_1, y1_1, x2_1, y2_1 = bbox1
    x1_2, y1_2, x2_2, y2_2 = bbox2

    # 判断两个边界框是否有水平和垂直方向上的重叠
    if x1_1 <= x2_2 and x2_1 >= x1_2 and y1_1 <= y2_2 and y2_1 >= y1_2:
        return True
    else:
        return False

def replace_text(text):
    # 去除每个子列表中的换行符  
    for sublist in text:  
        for i in range(len(sublist)):  
            if isinstance(sublist[i], str):  
                sublist[i] = sublist[i].replace('\n', '')  
    return text

def table_to_markdown(table):
    markdown = "|"
    for header in table[0]:
        markdown += " " + str(header) + " |"
    markdown += "\n|"
    for _ in range(len(table[0])):
        markdown += " --- |"
    markdown += "\n"
    for row in table[1:]:
        markdown += "|"
        for item in row:
            markdown += " " + str(item) + " |"
        markdown += "\n"
    return markdown

# %%
def get_page_info(doc, page_number):
	page = doc.load_page(page_number)
	lines_width = []
	x0_list = []
	text_list = []
	font_size_list = []
	doc_dict = page.get_text("dict", sort=True)
	
	width = doc_dict["width"]
	height = doc_dict["height"]
	doc_blocks = doc_dict["blocks"]
	
	page_info = []
	images_bbox = []
	tables_bbox = []
	tables_record = []
	try:
		doc_tabs = page.find_tables()
		tabs_count = len(doc_tabs.tables)
	except Exception as e:
		tabs_count = 0
	if tabs_count > 0:
		for i, table in enumerate(doc_tabs):
			tables_bbox.append({"number": i, "bbox": table.bbox, "text": replace_text(table.extract())})
	images_list = page.get_image_info()
	if len(images_list) > 0:
		for image in images_list:
			image_bbox = image.get("bbox")
			
			if image_bbox:
				image_wide = image_bbox[2] - image_bbox[0]
				image_height = image_bbox[3] - image_bbox[1]
				if abs(image_wide - width) > 10 and abs(image_height - height) > 10:
					images_bbox.append(image_bbox)
	
	for i in range(len(doc_blocks)):
		doc_block = doc_blocks[i]
		block_type = doc_block["type"]
		block_bbox = doc_block["bbox"]
		is_overlap_table = False
		is_overlap_image = False
		if tabs_count > 0:
			for tab in tables_bbox:
				tab_number = tab["number"]
				tab_bbox = tab["bbox"]
				tab_info = tab["text"]
				is_overlap_table = bbox_overlap(tab_bbox, block_bbox)
				if is_overlap_table:
					if tab_number not in tables_record:
						tables_record.append(tab_number)
						page_info.append(
							{"page_number": page_number + 1, "type": 2, "number": tab_number, "bbox": tab_bbox,
							 "text": tab_info})
					break
		if len(images_bbox) >= 1:
			for image_bbox in images_bbox:
				is_overlap_image = bbox_overlap(image_bbox, block_bbox)
				if is_overlap_image:
					if block_type == 1:
						page_info.append({"page_number": page_number + 1, "type": 1, "bbox": image_bbox})
					break
		if is_overlap_image or is_overlap_table:
			continue
		if block_type == 0:
			block_lines = doc_block["lines"]
			origin_y = 0
			for j in range(len(block_lines)):
				block_line = block_lines[j]
				line_spans = block_line["spans"]
				line_bbox = block_line["bbox"]
				y0 = round(line_bbox[1], 2)
				line_width = round(int(line_bbox[2]) - int(line_bbox[0]), 2)
				x0 = int(line_bbox[0])
				x0_list.append(x0)
				lines_width.append(line_width)
				line_text = ""
				line_dict = {"size": 0, "font": [], "line_width": line_width, "bbox": line_bbox, "text": ""}
				line_size = 0
				for k in range(len(line_spans)):
					line_span = line_spans[k]
					span_size = round(line_span["size"], 2)
					if span_size > line_size:
						line_size = span_size
					span_text = line_span["text"]
					line_text = line_text + span_text
				line_dict["size"] = line_size
				line_dict["text"] = line_text
				font_size_list.append(line_size)
				if y0 - origin_y > 1:
					page_info.append({"page_number": page_number + 1, "type": 0, "line_width": line_width, "x0": x0,
					                  "line_size": line_size, "text": line_text})
					text_list.append(line_text)
				else:
					if j >= 1:
						page_info[-1]["text"] = page_info[-1]["text"] + "\t" + line_dict["text"]
						page_info[-1]["line_width"] = page_info[-1]["line_width"] + line_width
						text_list[-1] = page_info[-1]["text"]
	return page_info, lines_width, x0_list, text_list, font_size_list

# %%
file = r'pdf\韵达股份 2020年年度报告-2021-04-30.pdf'
doc = fitz.open(file)

total_pages = doc.page_count
pdf_info = []
x0_list = []
lines_width = []
text_list = []
font_size_list = []

for i in tqdm(range(total_pages)):
    page_info, l_width, x0, texts, fone_size = get_page_info(doc, i)
    lines_width += l_width
    x0_list += x0
    text_list += texts
    font_size_list += fone_size
    if len(page_info) >= 1:
        pdf_info.append(page_info)

print("有效总页数：", len(pdf_info))
# Out:
#  46%|████▌     | 147/318 [04:55<05:43,  2.01s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17756\607823619.py in ?()
#       8 text_list = []
#       9 font_size_list = []
#      10
#      11 for i in tqdm(range(total_pages)):
# ---> 12     page_info, l_width, x0, texts, fone_size = get_page_info(doc, i)
#      13     lines_width += l_width
#      14     x0_list += x0
#      15     text_list += texts
#
# ~\AppData\Local\Temp\ipykernel_17756\1962064028.py in ?(doc, page_number)
#      20         except Exception as e:
#      21                 tabs_count = 0
#      22         if tabs_count > 0:
#      23                 for i, table in enumerate(doc_tabs):
# ---> 24                         tables_bbox.append({"number": i, "bbox": table.bbox, "text": replace_text(table.extract())})
#      25         images_list = page.get_image_info()
#      26         if len(images_list) > 0:
#      27                 for image in images_list:
#
# d:\anaconda3\envs\glm\lib\site-packages\fitz\table.py in ?(self)
#    1235             for cell in row.cells:
#    1236                 if cell is None:
#    1237                     cell_text = None
#    1238                 else:
# -> 1239                     cell_text = get_text(cell)
#    1240                 arr.append(cell_text)
#    1241             table_arr.append(arr)
#    1242
#
# d:\anaconda3\envs\glm\lib\site-packages\fitz\table.py in ?(cell)
#    1220                         if text and chars:
#    1221                             text += "\n"  # new span appended after linebreak
#    1222                         for char in chars:
#    1223                             bbox = Rect(char["bbox"])
# -> 1224                             if abs(bbox & cell) < 0.5 * abs(bbox):
#    1225                                 continue
#    1226                             text += char["c"]
#    1227
#
# d:\anaconda3\envs\glm\lib\site-packages\fitz\fitz.py in ?(self, x)
#    1170     def __and__(self, x):
#    1171         if not hasattr(x, "__len__") or len(x) != 4:
#    1172             raise ValueError("bad type op 2")
#    1173         r = Rect(self)
# -> 1174         return r.intersect(x)
#
# d:\anaconda3\envs\glm\lib\site-packages\fitz\fitz.py in ?(self, r)
#    1035     def intersect(self, r):
#    1036         """Restrict to common rect with rect-like r."""
#    1037         if not len(r) == 4:
#    1038             raise ValueError("Rect: bad seq len")
# -> 1039         r = Rect(r)
#    1040         if r.is_infinite:
#    1041             return self
#    1042         elif self.is_infinite:
#
# d:\anaconda3\envs\glm\lib\site-packages\fitz\fitz.py in ?(self, *args)
#     927     def __init__(self, *args):
# --> 928         self.x0, self.y0, self.x1, self.y1 = util_make_rect(args)
#     929         return None
#
# d:\anaconda3\envs\glm\lib\site-packages\fitz\fitz.py in ?(a)
#     435 def util_make_rect(a):
# --> 436     return _fitz.util_make_rect(a)
#
# ValueError: Rect: bad args

# %%
pdf_info
# Out:
# [[{'page_number': 1,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 1,
#    'type': 0,
#    'line_width': 185,
#    'x0': 207,
#    'line_size': 18.0,
#    'text': '韵达控股股份有限公司 '},
#   {'page_number': 1,
#    'type': 0,
#    'line_width': 120,
#    'x0': 239,
#    'line_size': 15.96,
#    'text': '2020 年年度报告 '},
#   {'page_number': 1,
#    'type': 0,
#    'line_width': 96,
#    'x0': 251,
#    'line_size': 15.96,
#    'text': '2021 年 04 月 '},
#   {'page_number': 1,
#    'type': 0,
#    'line_width': 6,
#    'x0': 534,
#    'line_size': 9.0,
#    'text': '1 '}],
#  [{'page_number': 2,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 221,
#    'x0': 189,
#    'line_size': 15.96,
#    'text': '第一节 重要提示、目录和释义 '},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 454,
#    'x0': 84,
#    'line_size': 14.04,
#    'text': '公司董事会、监事会及董事、监事、高级管理人员保证年度报告内容的真'},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '实、准确、完整，不存在虚假记载、误导性陈述或重大遗漏，并承担个别和连'},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 102,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '带的法律责任。 '},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 454,
#    'x0': 84,
#    'line_size': 14.04,
#    'text': '公司负责人聂腾云、主管会计工作负责人谢万涛及会计机构负责人(会计主'},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 430,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '管人员)刘辉声明：保证本年度报告中财务报告的真实、准确、完整。 '},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 299,
#    'x0': 84,
#    'line_size': 14.04,
#    'text': '所有董事均已出席了审议本报告的董事会会议。 '},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 454,
#    'x0': 84,
#    'line_size': 14.04,
#    'text': '本报告中涉及的未来发展规划及经营目标相关的前瞻性陈述，属于计划性'},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 486,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '事项，不构成公司对投资者的实质承诺，敬请投资者理性投资，注意投资风险。 '},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 454,
#    'x0': 84,
#    'line_size': 14.04,
#    'text': '公司需遵守《深圳证券交易所行业信息披露指引第 9 号—上市公司从事快'},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 172,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '递服务业务》的披露要求。 '},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 454,
#    'x0': 84,
#    'line_size': 14.04,
#    'text': '公司在本年度报告中详细阐述了未来可能发生的有关风险因素及对策，详'},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '见“第四节经营情况讨论与分析”之“九、公司未来发展的展望”中的“可能'},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 306,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '面临的风险及应对措施”，敬请投资者予以关注。 '},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 454,
#    'x0': 84,
#    'line_size': 14.04,
#    'text': '公司经本次董事会审议通过的利润分配预案为：以利润分配实施时股权登'},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '记日的公司总股本为基数，向全体股东每 10 股派发现金红利 0.49 元（含税），'},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 278,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '送红股 0 股（含税），不以公积金转增股本。 '},
#   {'page_number': 2,
#    'type': 0,
#    'line_width': 6,
#    'x0': 534,
#    'line_size': 9.0,
#    'text': '2 '}],
#  [{'page_number': 3,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 41,
#    'x0': 279,
#    'line_size': 18.0,
#    'text': '目录 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 486,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '第一节 重要提示、目录和释义 ..................................................................................................................... 2 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 486,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '第二节 公司简介和主要财务指标 ................................................................................................................. 5 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 486,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '第三节 公司业务概要 ..................................................................................................................................... 9 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 486,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '第四节 经营情况讨论与分析 ....................................................................................................................... 34 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 486,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '第五节 重要事项 ........................................................................................................................................... 73 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 486,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '第六节 股份变动及股东情况 ....................................................................................................................... 96 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 486,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '第七节 优先股相关情况 ............................................................................................................................. 103 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 486,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '第八节 可转换公司债券相关情况 ............................................................................................................. 104 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 486,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '第九节 董事、监事、高级管理人员和员工情况 ..................................................................................... 105 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 486,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '第十节 公司治理 .......................................................................................................................................... 115 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 486,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '第十一节 公司债券相关情况 ..................................................................................................................... 123 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 486,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '第十二节 财务报告 ..................................................................................................................................... 124 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 486,
#    'x0': 56,
#    'line_size': 14.04,
#    'text': '第十三节 备查文件目录 ............................................................................................................................. 318 '},
#   {'page_number': 3,
#    'type': 0,
#    'line_width': 6,
#    'x0': 534,
#    'line_size': 9.0,
#    'text': '3 '}],
#  [{'page_number': 4,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 4,
#    'type': 0,
#    'line_width': 36,
#    'x0': 281,
#    'line_size': 15.96,
#    'text': '释义 '},
#   {'page_number': 4,
#    'type': 2,
#    'number': 0,
#    'bbox': (57.39698757537424,
#     164.53997802734375,
#     534.446017748689,
#     689.1399993896484),
#    'text': [['释义项', '指', '释义内容'],
#     ['报告期', '指', '2020 年 1 月 1 日至 2020 年 12 月 31 日'],
#     ['上年同期', '指', '2019 年 1 月 1 日至 2019 年 12 月 31 日'],
#     ['公司/本公司/韵达/韵达股份/韵达控股', '指', '韵达控股股份有限公司'],
#     ['韵达货运', '指', '上海韵达货运有限公司'],
#     ['上海罗颉思', '指', '上海罗颉思投资管理有限公司'],
#     ['上海丰科', '指', '上海丰科企业管理合伙企业（有限合伙）'],
#     ['桐庐韵嘉', '指', '桐庐韵嘉投资管理合伙企业（有限合伙）'],
#     ['桐庐韵科', '指', '桐庐韵科投资管理合伙企业（有限合伙）'],
#     ['上海太富祥川', '指', '上海太富祥川股权投资基金合伙企业（有限合伙）'],
#     ['宁波招银', '指', '宁波招银成长拾号投资合伙企业（有限合伙）'],
#     ['深圳富海臻界', '指', '深圳富海臻界物流二号投资企业（有限合伙）'],
#     ['宁波中钰', '指', '宁波中钰股权投资合伙企业（有限合伙）'],
#     ['宁波云晖景盛', '指', '宁波云晖景盛投资管理合伙企业（有限合伙）'],
#     ['福杉投资', '指', '宁波梅山保税港区福杉投资有限公司'],
#     ['东普科技', '指', '上海东普信息科技有限公司'],
#     ['', '', '宁波新海电气股份有限公司，为韵达控股股份有限公司的前身，于 2017 年'],
#     ['新海股份', '指', None],
#     [None, None, '1 月更名为韵达控股股份有限公司'],
#     ['', '', None],
#     ['', '', '本公司前身宁波新海电气股份有限公司以截至置出资产评估基准日全部资'],
#     [None, None, '产及负债与上海韵达货运有限公司全体股东持有的上海韵达货运有限公司'],
#     ['重大资产重组', '指', None],
#     [None, None, '100%股权的等值部分进行置换，并以发行股份的方式自上海韵达货运有限'],
#     ['', '', None],
#     [None, None, '公司全体股东处购买置入资产与置出资产差额部分'],
#     ['《公司法》', '指', '《中华人民共和国公司法》'],
#     ['《证券法》', '指', '《中华人民共和国证券法》'],
#     ['《公司章程》', '指', '《韵达控股股份有限公司章程》'],
#     ['深交所', '指', '深圳证券交易所'],
#     ['元、万元、亿元', '指', '人民币元、人民币万元、人民币亿元']]},
#   {'page_number': 4,
#    'type': 0,
#    'line_width': 6,
#    'x0': 534,
#    'line_size': 9.0,
#    'text': '4 '}],
#  [{'page_number': 5,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 5,
#    'type': 0,
#    'line_width': 237,
#    'x0': 181,
#    'line_size': 15.96,
#    'text': '第二节 公司简介和主要财务指标 '},
#   {'page_number': 5,
#    'type': 0,
#    'line_width': 75,
#    'x0': 56,
#    'line_size': 12.0,
#    'text': '一、公司信息 '},
#   {'page_number': 5,
#    'type': 2,
#    'number': 0,
#    'bbox': (57.4200013478597,
#     179.89996337890625,
#     534.4911174158896,
#     440.92999267578125),
#    'text': [['股票简称', '韵达股份', '股票代码', '002120'],
#     ['股票上市证券交易所', '深圳证券交易所', None, None],
#     ['公司的中文名称', '韵达控股股份有限公司', None, None],
#     ['公司的中文简称', '韵达股份', None, None],
#     ['公司的外文名称（如有）', 'YUNDA Holding Co., Ltd.', None, None],
#     ['公司的外文名称缩写（如有）', 'YUNDA Corp.', None, None],
#     ['公司的法定代表人', '聂腾云', None, None],
#     ['注册地址', '浙江省慈溪市崇寿镇永清南路 8 号', None, None],
#     ['注册地址的邮政编码', '315334', None, None],
#     ['办公地址', '上海市青浦区盈港东路 6679 号', None, None],
#     ['办公地址的邮政编码', '201700', None, None],
#     ['公司网址', 'www.yundaex.com', None, None],
#     ['电子信箱', 'ir@yundaex.com', None, None]]},
#   {'page_number': 5,
#    'type': 0,
#    'line_width': 124,
#    'x0': 56,
#    'line_size': 12.0,
#    'text': '二、联系人和联系方式 '},
#   {'page_number': 5,
#    'type': 2,
#    'number': 1,
#    'bbox': (57.4200013478597,
#     495.06998443603516,
#     534.4911174158896,
#     615.4299926757812),
#    'text': [['', '董事会秘书', '证券事务代表'],
#     ['姓名', '符勤', '杨红波'],
#     ['联系地址', '上海市青浦区盈港东路 6679 号', '上海市青浦区盈港东路 6679 号'],
#     ['电话', '021-39296789', '021-39296789'],
#     ['传真', '021-39296863', '021-39296863'],
#     ['电子信箱', 'ir@yundaex.com', 'ir@yundaex.com']]},
#   {'page_number': 5,
#    'type': 0,
#    'line_width': 136,
#    'x0': 56,
#    'line_size': 12.0,
#    'text': '三、信息披露及备置地点 '},
#   {'page_number': 5,
#    'type': 2,
#    'number': 2,
#    'bbox': (57.4200013478597,
#     669.6399841308594,
#     534.4911174158896,
#     729.6999664306641),
#    'text': [['公司选定的信息披露媒体的名称', '《中国证券报》、《上海证券报》、《证券时报》、《证券日报》'],
#     ['登载年度报告的中国证监会指定网站的网址', 'www.cninfo.com.cn'],
#     ['公司年度报告备置地点', '公司董事会办公室']]},
#   {'page_number': 5,
#    'type': 0,
#    'line_width': 6,
#    'x0': 534,
#    'line_size': 9.0,
#    'text': '5 '}],
#  [{'page_number': 6,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 6,
#    'type': 0,
#    'line_width': 100,
#    'x0': 56,
#    'line_size': 12.0,
#    'text': '四、注册变更情况 '},
#   {'page_number': 6,
#    'type': 2,
#    'number': 0,
#    'bbox': (57.454738215396276,
#     110.77996826171875,
#     534.4955027054767,
#     186.44000244140625),
#    'text': [['组织机构代码', '91330200144745634H'],
#     ['公司上市以来主营业务的变化情况（如', ''],
#     [None, '报告期内无变更'],
#     ['有）', None],
#     [None, ''],
#     ['历次控股股东的变更情况（如有）', '报告期内无变更']]},
#   {'page_number': 6,
#    'type': 0,
#    'line_width': 100,
#    'x0': 56,
#    'line_size': 12.0,
#    'text': '五、其他有关资料 '},
#   {'page_number': 6,
#    'type': 0,
#    'line_width': 101,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '公司聘请的会计师事务所 '},
#   {'page_number': 6,
#    'type': 2,
#    'number': 1,
#    'bbox': (57.454738215396276,
#     265.9429931640625,
#     534.4955027054767,
#     349.489990234375),
#    'text': [['会计师事务所名称', '容诚会计师事务所（特殊普通合伙）'],
#     ['会计师事务所办公地址', '北京市西城区阜成门外大街 22 号 1 幢外经贸大厦 901-22 至 901-26'],
#     ['签字会计师姓名', '廖金辉、毛燕庆']]},
#   {'page_number': 6,
#    'type': 0,
#    'line_width': 200,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '公司聘请的报告期内履行持续督导职责的保荐机构 '},
#   {'page_number': 6,
#    'type': 0,
#    'line_width': 76,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '□ 适用 √ 不适用  '},
#   {'page_number': 6,
#    'type': 0,
#    'line_width': 200,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '公司聘请的报告期内履行持续督导职责的财务顾问 '},
#   {'page_number': 6,
#    'type': 0,
#    'line_width': 76,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '□ 适用 √ 不适用  '},
#   {'page_number': 6,
#    'type': 0,
#    'line_width': 160,
#    'x0': 56,
#    'line_size': 12.0,
#    'text': '六、主要会计数据和财务指标 '},
#   {'page_number': 6,
#    'type': 0,
#    'line_width': 182,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '公司是否需追溯调整或重述以前年度会计数据 '},
#   {'page_number': 6,
#    'type': 0,
#    'line_width': 49,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '□ 是 √ 否  '},
#   {'page_number': 6,
#    'type': 2,
#    'number': 2,
#    'bbox': (41.58428709847586,
#     556.030029296875,
#     534.4955027054767,
#     752.3159637451172),
#    'text': [['', '2020 年', '2019 年', '本年比上年增减', '2018 年'],
#     ['营业收入（元）',
#      '33,500,425,643.17',
#      '34,404,046,688.25',
#      '-2.63%',
#      '13,855,989,746.71'],
#     ['归属于上市公司股东的净利润（元）',
#      '1,404,493,896.78',
#      '2,647,196,861.81',
#      '-46.94%',
#      '2,697,993,712.88'],
#     ['归属于上市公司股东的扣除非经常性', '', '', '', ''],
#     [None,
#      '1,209,764,937.89',
#      '2,413,878,859.89',
#      '-49.88%',
#      '2,135,008,077.06'],
#     ['损益的净利润（元）', None, None, None, None],
#     [None, '', '', '', ''],
#     ['经营活动产生的现金流量净额（元）',
#      '2,183,637,598.99',
#      '5,035,636,370.68',
#      '-56.64%',
#      '3,714,468,466.28'],
#     ['基本每股收益（元/股）', '0.48', '0.91', '-47.25%', '0.95'],
#     ['稀释每股收益（元/股）', '0.48', '0.91', '-47.25%', '0.95'],
#     ['加权平均净资产收益率', '10.09%', '21.22%', '下降 11.13 个百分点', '28.84%'],
#     ['', '2020 年末', '2019 年末', '本年末比上年末增减', '2018 年末']]},
#   {'page_number': 6,
#    'type': 0,
#    'line_width': 6,
#    'x0': 534,
#    'line_size': 9.0,
#    'text': '6 '}],
#  [{'page_number': 7,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 7,
#    'type': 2,
#    'number': 0,
#    'bbox': (41.560001373291016,
#     72.32849884033203,
#     534.5199916673744,
#     112.37000274658203),
#    'text': [['总资产（元）',
#      '29,500,766,142.95',
#      '22,496,654,773.40',
#      '31.13%',
#      '18,080,928,087.75'],
#     ['归属于上市公司股东的净资产（元）',
#      '14,377,889,835.81',
#      '13,462,844,669.99',
#      '6.80%',
#      '11,460,426,396.95']]},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '公司最近三个会计年度扣除非经常性损益前后净利润孰低者均为负值，且最近一年审计报告显示公司持续经营能力存在不确'},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 20,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '定性 '},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 49,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '□ 是 √ 否  '},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 173,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '扣除非经常损益前后的净利润孰低者为负值 '},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 49,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '□ 是 √ 否  '},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 196,
#    'x0': 56,
#    'line_size': 12.0,
#    'text': '七、境内外会计准则下会计数据差异 '},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 419,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '1、同时按照国际会计准则与按照中国会计准则披露的财务报告中净利润和净资产差异情况 '},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 76,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '□ 适用 √ 不适用  '},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 407,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '公司报告期不存在按照国际会计准则与按照中国会计准则披露的财务报告中净利润和净资产差异情况。 '},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 419,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '2、同时按照境外会计准则与按照中国会计准则披露的财务报告中净利润和净资产差异情况 '},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 76,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '□ 适用 √ 不适用  '},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 407,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '公司报告期不存在按照境外会计准则与按照中国会计准则披露的财务报告中净利润和净资产差异情况。 '},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 136,
#    'x0': 56,
#    'line_size': 12.0,
#    'text': '八、分季度主要财务指标 '},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 38,
#    'x0': 502,
#    'line_size': 9.0,
#    'text': '单位：元 '},
#   {'page_number': 7,
#    'type': 2,
#    'number': 1,
#    'bbox': (57.46125137805939,
#     551.949951171875,
#     534.5199916673744,
#     667.7799987792969),
#    'text': [['', '第一季度', '第二季度', '第三季度', '第四季度'],
#     ['营业收入',
#      '5,624,623,279.64',
#      '8,692,997,527.33',
#      '8,769,715,836.12',
#      '10,413,089,000.08'],
#     ['归属于上市公司股东的净利润',
#      '333,972,438.02',
#      '347,027,887.18',
#      '339,015,692.76',
#      '384,477,878.82'],
#     ['归属于上市公司股东的扣除非经', '', '', '', ''],
#     [None,
#      '259,825,657.13',
#      '299,627,417.77',
#      '294,895,271.01',
#      '355,416,591.98'],
#     ['常性损益的净利润', None, None, None, None],
#     [None, '', '', '', ''],
#     ['经营活动产生的现金流量净额',
#      '-564,576,931.27',
#      '895,229,924.19',
#      '527,538,760.73',
#      '1,325,445,845.34']]},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 371,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '上述财务指标或其加总数是否与公司已披露季度报告、半年度报告相关财务指标存在重大差异 '},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 49,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '□ 是 √ 否  '},
#   {'page_number': 7,
#    'type': 0,
#    'line_width': 6,
#    'x0': 534,
#    'line_size': 9.0,
#    'text': '7 '}],
#  [{'page_number': 8,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 8,
#    'type': 0,
#    'line_width': 160,
#    'x0': 56,
#    'line_size': 12.0,
#    'text': '九、非经常性损益项目及金额 '},
#   {'page_number': 8,
#    'type': 0,
#    'line_width': 76,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '√ 适用 □ 不适用  '},
#   {'page_number': 8,
#    'type': 0,
#    'line_width': 38,
#    'x0': 502,
#    'line_size': 9.0,
#    'text': '单位：元 '},
#   {'page_number': 8,
#    'type': 2,
#    'number': 0,
#    'bbox': (57.58500146865845,
#     153.739990234375,
#     534.8949928283691,
#     581.9633178710938),
#    'text': [['项目', '2020 年金额', '2019 年金额', '2018 年金额', '说明'],
#     ['非流动资产处置损益（包括已计提资产减', '-1,588,942.22', '', '', '主要系非流动资产毁损报废损失所致'],
#     [None, None, '-111,884,013.87', '-58,309,553.01', None],
#     ['值准备的冲销部分）', None, None, None, None],
#     [None, None, '', '', None],
#     ['计入当期损益的政府补助（与企业业务密', '88,951,356.42', '', '', ''],
#     ['切相关，按照国家统一标准定额或定量享', None, '209,095,219.92', '62,674,185.61', None],
#     ['受的政府补助除外）', None, '', '', None],
#     ['计入当期损益的对非金融企业收取的资金', '4,246,851.27', '', '', ''],
#     [None, None, '3,990,158.50', '1,875,390.96', None],
#     ['占用费', None, None, None, None],
#     [None, None, '', '', None],
#     ['委托他人投资或管理资产的损益', '', '', '170,521,271.58', ''],
#     ['与公司正常经营业务无关的或有事项产生', '-3,523,625.22', '', '', '未决诉讼'],
#     [None, None, '762,102.07', '-1,924,548.50', None],
#     ['的损益', None, None, None, None],
#     [None, None, '', '', None],
#     ['除同公司正常经营业务相关的有效套期保', '172,719,440.19', '', '', ''],
#     ['值业务外，持有交易性金融资产、衍生金', None, None, None, None],
#     ['融资产、交易性金融负债、衍生金融负债', None, None, None, None],
#     ['产生的公允价值变动损益，以及处置交易', None, '236,876,668.90', '588,343,482.92', None],
#     ['性金融资产、衍生金融资产、交易性金融', None, '', '', None],
#     ['负债、衍生金融负债和其他债权投资取得', None, None, None, None],
#     ['的投资收益', None, None, None, None],
#     ['单独进行减值测试的应收款项、合同资产', '', '', '', ''],
#     [None, None, '1,944,324.23', '', None],
#     ['减值准备转回', None, None, None, None],
#     [None, None, '', '', None],
#     ['除上述各项之外的其他营业外收入和支出',
#      '-6,350,013.88',
#      '-12,610,374.56',
#      '-9,734,163.08',
#      ''],
#     ['减：所得税影响额', '61,150,246.86', '94,567,303.84', '188,508,563.35', ''],
#     ['少数股东权益影响额（税后）', '-1,424,139.19', '288,779.43', '1,951,867.31', ''],
#     ['合计', '194,728,958.89', '233,318,001.92', '562,985,635.82', '--']]},
#   {'page_number': 8,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '对公司根据《公开发行证券的公司信息披露解释性公告第 1 号——非经常性损益》定义界定的非经常性损益项目，以及把《公'},
#   {'page_number': 8,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '开发行证券的公司信息披露解释性公告第 1 号——非经常性损益》中列举的非经常性损益项目界定为经常性损益的项目，应'},
#   {'page_number': 8,
#    'type': 0,
#    'line_width': 38,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '说明原因 '},
#   {'page_number': 8,
#    'type': 0,
#    'line_width': 76,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '□ 适用 √ 不适用  '},
#   {'page_number': 8,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '公司报告期不存在将根据《公开发行证券的公司信息披露解释性公告第 1 号——非经常性损益》定义、列举的非经常性损益'},
#   {'page_number': 8,
#    'type': 0,
#    'line_width': 155,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '项目界定为经常性损益的项目的情形。 '},
#   {'page_number': 8,
#    'type': 0,
#    'line_width': 6,
#    'x0': 534,
#    'line_size': 9.0,
#    'text': '8 '}],
#  [{'page_number': 9,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 156,
#    'x0': 221,
#    'line_size': 15.96,
#    'text': '第三节 公司业务概要 '},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 184,
#    'x0': 56,
#    'line_size': 12.0,
#    'text': '一、报告期内公司从事的主要业务 '},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 398,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '公司需遵守《深圳证券交易所行业信息披露指引第 9 号——上市公司从事快递服务业务》的披露要求 '},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 265,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '（一）报告期内公司从事的主要业务、产品及其用途，经营模式等 '},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 70,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '1、公司主营业务 '},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '韵达股份是国内领先的快递综合服务提供商。公司以“韵达+”理念为引领，以科技创新、精细管理为驱动，践行“绿色快'},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '递，智领未来”的新发展观，实施“守正开放、多元协同、一超多强”的发展战略，用优秀的快递服务品质辐射周边市场、周'},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '边需求、周边产品，构建“以快递为核心，聚合周边产业、新业务、新业态协同发展”的多层次综合物流生态圈，追求“向客'},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 258,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '户提供极致的快递服务体验和无与伦比的快递时效”的发展愿景。 '},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 97,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '2、公司主要产品与服务 '},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '公司以服务实体经济为宗旨，以满足客户需求为导向，做大做强快递核心主业，巩固并不断扩大标准快递业务的品牌优'},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '势、规模优势和市场优势；同时，将优质的服务品质进行流量转化，积极实施快递业务“客户分群、产品分层”策略，大力发'},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '展菜鸟裹裹、韵达特快等高附加值时效产品，集中精力开拓韵达特快客户群；另外，用快递流量积极嫁接周边市场，陆续布'},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 487,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '局了韵达供应链、韵达国际、韵达冷链、韵达科技以及韵达末端服务、广告宣传等周边产业链，为提升国民经济运行效率、'},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 230,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '推动新经济发展、提高居民消费水平等提供基础性支撑。 '},
#   {'page_number': 9,
#    'type': 0,
#    'line_width': 6,
#    'x0': 534,
#    'line_size': 9.0,
#    'text': '9 '}],
#  [{'page_number': 10,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 10,
#    'type': 1,
#    'bbox': (88.23200225830078,
#     83.49996948242188,
#     513.3419799804688,
#     363.8499755859375)},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 5,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': ' '},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 314,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■快递产品：标准快递、时效产品（韵达特快、裹裹寄件、当日达、次日达）等 '},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 89,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■同城即配：同城派送 '},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 458,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■增值服务：代收货款、保价业务、门店调拨、签单返还、开放平台、逆向物流、隐私面单、送前电联、预约配送等 '},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■韵达供应链：仓配一体、仓店调拨、数据和软件服务、整体解决方案等，通过云技术形成“万仓联盟”，为上下游客户'},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 137,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '提供全方位的仓配一体化解决方案 '},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■韵达国际：标准进口&出口服务（国际专线、国际特惠、国际小包、国际重货、FBA等）、仓储（保税仓储、海外仓'},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 92,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '储）、转运等相关业务 '},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■韵达冷链：致力于提供冷链全流程完整的解决方案，可以提供存储、拆零、分拣、配货、包装、贴标、流通加工等仓'},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 272,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '管服务，以及干线运输、城市配送、末端配送等一体化冷链物流服务 '},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 88,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '3、公司快递经营模式 '},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '公司采用“枢纽中转自营与末端网络加盟”的快递经营模式。自营方面，所有枢纽转运中心的设立、投资、运营、管理均'},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '由公司总部负责，实现对核心资源、干线网络及服务品质的有效控制力；加盟方面，全网的收派两端、业务开拓和客户体验'},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 476,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '主要由具备快递经营许可、资质优良的加盟商提供服务，最终形成“枢纽转运中心和干线网络自营、终端揽派加盟相结合”'},
#   {'page_number': 10,
#    'type': 0,
#    'line_width': 11,
#    'x0': 529,
#    'line_size': 9.0,
#    'text': '10 '},
#   {'page_number': 10,
#    'type': 1,
#    'bbox': (70.95700073242188,
#     710.2999877929688,
#     524.447021484375,
#     840.4099731445312)}],
#  [{'page_number': 11,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 158,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '的网络化、平台化、扁平化运营模式。 '},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 228,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '（二）行业发展阶段、周期性特点以及公司所处行业地位 '},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 142,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '1、快递产业持续获享政策红利支持 '},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 468,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '快递物流产业是联结第一、第二产业以及国际贸易的新型服务业，一端连着供给侧，一端连着需求侧，具有经济先导、'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '民生保障等特性，在提升经济资源配置效率、推动电子商务经济发展、降低全社会物流总成本、提高国民生活水平等方面发'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '挥着战略支撑作用。同时，快递产业还是实践“大众创业、万众创新”、吸纳就业的重要载体，是“众人做事，集众智集众力，'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '众人共享”的好业态、好模式，快递小哥是“美好生活的创造者、守护者”。在新时代背景下，快递产业作为新经济、新服务、'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '新业态的代表，当前正处于信息化、数字化、智能化、智慧化之难得的战略发展机遇期，备受政策红利支持，党和政府及相'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 119,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '关监管部门颁布了诸多政策。 '},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '继2009年修订《中华人民共和国邮政法》并首次从法律层面明确快递行业的法律地位之后，2018年5月1日实施的《快递'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '暂行条例》又将“持续推动快递业健康发展”、“保障快递安全”、“保护用户合法权益”作为促进我国快递业发展和治理体系现'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 308,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '代化的核心主题，保障我国快递业实现由大到强的转变，促进高质量的发展。 '},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '国家邮政局发布的《快递业发展“十三五”规划》指出，2020年我国将基本建成普惠城乡、技术先进、服务优质、安全高'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 281,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '效、绿色节能的快递服务体系，形成覆盖全国、联通国际的服务网站。 '},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '2020年2月5日，国务院常务会议提出，对运输防控重点物资和提供公共交通、生活服务、邮政快递收入免征增值税，疫'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 491,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '情税费优惠政策期限延至2020年12月31日；交通运输部发布了《关于新冠肺炎疫情防控期间免收收费公路车辆通行费的通知》，'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 452,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '交通运输部关于《统筹推进疫情防控和经济社会发展交通运输工作的实施意见》中明确指出要全力确保物流畅通。 '},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '2020年3月3日，李克强总理主持召开国务院常务会议，指出推动交通运输、快递等物流业加快复工复产，实现稳定发展。'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 415,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '各地要对邮政和各种所有制快递企业给予一视同仁的通行便利，打破乡村、社区“最后一公里”投递障碍。 '},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '2020年4月，国家邮政局、工业和信息化部印发了《关于促进快递业与制造业深度融合发展的意见》，指出要探索建立'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '符合我国国情的物流业制造业融合发展模式，推动快递业提升服务能力，健全产品体系，创新发展供应链，构建与制造业高'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 326,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '质量发展相适应的快递物流服务体系，形成快递业与制造业深度融合的发展格局。 '},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '2020年5月，国家发展改革委和交通运输部联合发布了《关于进一步降低物流成本的实施意见》，指出加快发展智慧物'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 290,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '流，积极发展绿色物流。并且要深化关键环节改革，降低物流制度成本。 '},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '2020年8月，交通运输部《关于推动交通运输领域新型基础设施建设的指导意见》中明确了“打造融合高效的智慧交通基'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 392,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '础设施”的任务，对于“智慧邮政”方面要推广邮政快递转运中心自动化分拣设备、机械化装卸设备。 '},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '2020年9月，国务院办公厅发布了《关于以新业态新模式引领新型消费加快发展的意见》指出 “加快建设国际寄递物流'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '服务体系，统筹推进国际物流供应链建设，降低物流成本。”国家发展改革委、工业和信息化部等14部门联合印发了《推动'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '物流业制造业深度融合创新发展实施方案》，提出到2025年，物流业在促进实体经济降本增效、供应链协同、制造业高质量'},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 343,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '发展等方面作用显著增强，要“探索建立符合我国国情的物流业制造业融合发展模式”。 '},
#   {'page_number': 11,
#    'type': 0,
#    'line_width': 10,
#    'x0': 530,
#    'line_size': 9.0,
#    'text': '11 '}],
#  [{'page_number': 12,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '我国最新发布的“十四五规划”和二〇三五年远景目标指出，要加快发展现代物流等服务业，构建现代物流体系，加快推'},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '进服务业数字化。中国物流行业要重点着力于智慧物流的深化应用、物流供应链模式创新、可持续发展的绿色低碳物流等方'},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 209,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '面的建设，推动中国物流行业进入转型升级新时期。 '},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 142,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '2、快递包裹“泛在化”时代已经到来 '},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 151,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '（1）移动互联网技术进入全民化时代 '},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '互联网让人类社交方式突破了时空限制，开创了社交新纪元。在互联网基础设施建设、移动终端设备普及和政府“提速'},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 483,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '降费”红利政策等因素积极推动下，我国网络用户、网络购物用户、网络支付用户三项数据连续多年保持着持续增长态势。 '},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 358,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■网络用户方面：据中国互联网络信息中心发布的《第47次中国互联网络发展状况统计报告》'},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 113,
#    'x0': 425,
#    'line_size': 9.0,
#    'text': '（以下简称“CNNIC报告”），'},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '截至2020年12月，我国网民规模高达9.89亿，较2020年3月增长8540万，互联网普及率达70.4%，较一季度末提升近6个百分'},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '点；我国手机网民规模达9.86亿，较2020年3月增长8885万，网民使用手机上网的比例达99.7%，较一季度末提升0.4个百分'},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 487,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '点；农村网民规模达3.09亿，占网民总体的31.3%，较2020年3月增长5471万，城镇网民规模达6.8亿，占网民总体的68.7%，'},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 106,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '较2020年3月增长3069万。 '},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■网络支付方面：截至2020年12月，我国网络支付用户规模达8.54亿，较2020年3月增长8636万，占网民整体的86.4%；'},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 325,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '手机网络支付用户规模达8.53亿，较2020年3月增长8744万，占手机网民的86.5%。 '},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■网购用户方面：截至2020年12月，我国网络购物用户规模达7.82亿，较2020年3月增长7215万，占网民整体的79.1%；'},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 325,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '手机网络购物用户规模达7.81亿，较2020年3月增长7309万，占手机网民的79.2%。 '},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '近年来，我国网络扶贫行动向纵深发展取得实质进展，带动农村特别是边远贫困地区人口加速转网化，报告期农村网民'},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 487,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '的增长远高于城镇网民增长数量。乐观预计，在移动互联网全民化浪潮及人均可支配收入持续增长背景下，我国网络用户、'},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '网络购物用户还有较大的渗透空间，移动互联网技术的应用已进入全民化时代，超过10亿人口的网络用户将长期释放庞大的'},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 68,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '网购市场红利。 '},
#   {'page_number': 12,
#    'type': 1,
#    'bbox': (70.9000015258789,
#     546.7999877929688,
#     524.4400024414062,
#     709.7899780273438)},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 5,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': ' '},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 169,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '（2）立体式网购经济正加速释放增量包裹 '},
#   {'page_number': 12,
#    'type': 0,
#    'line_width': 11,
#    'x0': 529,
#    'line_size': 9.0,
#    'text': '12 '}],
#  [{'page_number': 13,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■电商平台多元化：近年来，我国移动互联网与内需消费深度融合，电子商务经济继续保持着蓬勃的发展态势，以创新'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '的营销方式和商业模式实现流量变现，呈现出了全新的、平台多元化的网络购物新生态。一方面，淘宝、京东商城、苏宁易'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '购等第一代大型综合电商平台稳健发展，在用户流量、全品类交易、渠道下沉、培育增量GMV等方面持续迭代；另一方面，'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '以拼多多、微商等为代表的第二代新型电商平台，一是没有购物车，二是省去对消费者网购习惯的培育成本，三是基于社交'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '裂变的拼团模式，四是通过百亿补贴、趣味游戏、新客优惠、高频低价等促销手段，快速聚拢起已经成熟化的庞大网购用户'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '流量，以更快的速度迅速崛起；同时，一批小而美、模式独特的垂直电商也不断涌现，如：以小红书等为代表的基于消费体'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '验的“种草”传播，以淘系、京东、苏宁等为代表的基于线上线下融合的O2O，以天猫国际、京东全球购为代表的基于买手精'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '选的跨境购等，开启了我国电商发展的新阶段；而且，快手、抖音、B站等娱乐大厂通过将娱乐流量进行高效转化，原本作'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 362,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '为商业引流的渠道工具，目前也正快速成长为独立的第三代基于直播带货的综合电商平台。 '},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■渠道下沉：我国三线城市及以下区域为主的“下沉市场”正接管电商流量增长的重任，这里包括近300个地级市、3000'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '多个县城、4万个乡镇、66万个村庄，以及将近10亿的消费人口，网购潜力如同“大水里的大鱼”，逐渐成为互联网下半场流'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '量开发的新价值洼地。自2018年以来，在高性价比便捷快递服务网络的有力支撑下，社交拼团模式迅速崛起，拼多多、淘宝、'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '京东等大型综合电商平台快速推进渠道下沉引流工作。通过重组渠道下沉品牌、创新C2M供销模式、塑造廉价品牌工厂、'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '引入地理标志产品等模式，砍掉传统的采购、批发、运输、零售等中间商供应链环节，把老百姓日常需要的、质优价廉的实'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '惠商品从工厂、农田、山头直通家庭、餐桌和消费者。同时，通过新客奖励、复购优惠、现金补贴、X.99元包邮、累购返现、'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '会员送券等一系列多、快、好、省的营销模式，将营销学、行为学、心理学精巧结合，精心培育三线以下城市及县域、乡镇、'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 344,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '农村等数亿购物人群的网络购物习惯，引导他们把日常购物的流量由线下往线上转移。 '},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■农产品上行：2017年以来，以拼多多、淘宝、京东等为代表的电商平台持续下沉、深耕农村市场，农村电子商务已经'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '发展成为高效链接农产品供需两端、助力农产品上行的重要流通渠道，譬如云南的松茸、陕西的苹果、四川的猕猴桃、杭州'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '天目山的小甘薯、阳澄湖大闸蟹等具有浓郁地方特色的绿色特产、农副产品通过网购走向全国。同时，国家也先后出台一系'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '列专项政策予以大力支持。2020年7月，国家邮政局启动“快递进村”工程，并制定了《“快递进村”三年行动方案（2020-2022'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '年）》，明确到2022年年底，符合条件的建制村基本实现“村村通快递”。2021年1月4日，国务院《关于全面推进乡村振兴加'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '快农业农村现代化的意见》明确指出：“全面促进农村消费”，“加快完善县乡村三级农村物流体系，深入推进电子商务进农'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '村和农产品出村进城，推动城乡生产与消费有效对接”，“加快实施农产品仓储保鲜冷链物流设施建设工程，推进田头小型仓'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 294,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '储保鲜冷链设施、产地低温直销配送中心、国家骨干冷链物流基地建设”。 '},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '2020年4月21日，拼多多发布《2019年农产品上行发展报告》显示，2019年平台农（副）产品活跃商家数量达58.6万，'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '较上年同比增长142%，直连农业生产者超过1200万；平台农（副）产品成交额达1364亿元，较上年同期增长109%；平台农'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '（副）产品年活跃买家数达2.4亿，较上年同比增长174%，复购率超过70%。另外，根据CNNIC及商务部相关统计数据：截'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '至2020年末，农村网民数量突破3.09亿，电子商务进农村实现对832个贫困县全覆盖，全国农村网络零售额由2014年的1800'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '亿元，增长到2020年的1.79万亿元，6年交易额增长了近10倍。我们预计，随着下沉区域网络用户持续增长及农产品上行持'},
#   {'page_number': 13,
#    'type': 0,
#    'line_width': 11,
#    'x0': 529,
#    'line_size': 9.0,
#    'text': '13 '}],
#  [{'page_number': 14,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 362,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '续推进，工业品和农产品通过电商在城乡之间将高效流通，持续向快递产业释放包裹红利。 '},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■直播带货：随着快手、抖音、哔哩哔哩等视频大平台娱乐流量的有效转化，粉丝经济、网红经济、直播经济爆炸式发'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '展，公/私域流量下的直播带货已经成为高度产业化的“现象级”营销模式，并开启了电商与直播、短视频内容提供商的深度'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '融合，实现商品在全渠道、全客群的分层式、精准式营销。而且，直播的现实感和直播场景的灵活化，赋予了网红带货产品'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '的广泛性，包括但不限于汽车、餐饮、家具、家电、美妆、服装、数码、日用品等领域，只要可以放进购物车，万物皆可播。'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 190,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '目前，“直播带货”已经展现了强大的流量威力。 '},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '报告期，网络直播已经成为“线上引流+实体消费”的数字经济新模式，带动电商直播产业蓬勃发展。根据CNNIC及商务'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '部相关统计数据：截至2020年12月，我国网络直播用户规模达6.17亿，较2020年3月增长5703万，占网民整体的62.4%，其中：'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '电商直播用户规模已达3.88亿，占网民整体的39.2%，近66.2%的直播用户直接转化为网购消费者。另据艾媒咨询发布的'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '《2020-2021中国在线直播行业年度研究报告》显示，2020年全国电商直播超过2000万场；2017-2020直播电商行业市场规模'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '分别为196亿元、1354亿元、4338亿元和9610亿元，市场规模三年增长率高达49倍。因此，随着5G技术覆盖率提升以及疫情'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '对居民消费场景、消费习惯的改变，基于“宅文化”下直播网购所呈现的娱乐性、互动性、体验性优势，预计电商直播将具备'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 428,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '较大发展空间，可以说网红带货已经成为打开新经济大门的新钥匙，已经成为刺激网络消费增长的新动能。 '},
#   {'page_number': 14,
#    'type': 1,
#    'bbox': (56.70000076293945,
#     381.2900085449219,
#     538.5999755859375,
#     557.6400146484375)},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■生活场景快递化：“柴米油盐酱醋茶，快递包裹送到家”。随着线上消费高频和网购习惯的养成，以及驿站、快递超市、'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '智能快递柜等末端服务基础设施的普及，同时公众号、小程序、APP等寄递渠道多元便捷、触手可及，人们生活场景快递化'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '的趋势越来越明显。快递的应用场景正充满生活的每一个角落：从同城鲜花、蛋糕、菜场、商超的配送，到代买药、代取送'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 487,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '物等跑腿业务；从高校开学季、毕业季、寒暑假等物品的寄递，到亲戚朋友之间个人物品的递送、赠送；从服装、化妆品、'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '小电器等耐用品的退换货，到工厂、维修店的零部件配送，收寄包裹已经成为老百姓生活中的日常事。生活场景快递化，将'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 272,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '持续改变人们之间物品的流通方式，也将释放越来越多的快递包裹。 '},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 469,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '2020年我国快递包裹总量为833.6亿件，预计2021年快递包裹总量将达千亿级。展望未来，在“互联网+消费”深度融合、'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 481,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '电商渠道加速下沉、城乡发展齐头并进作用下，我国电子商务经济的刚需消费效应、消费分级效应和持续渗透效应愈加明'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 481,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '显，新的网购需求正加快培育；同时，高品质快递服务正同步跟进，快递的应用场景将广泛延伸至通商业、通消费、通贸'},
#   {'page_number': 14,
#    'type': 0,
#    'line_width': 11,
#    'x0': 529,
#    'line_size': 9.0,
#    'text': '14 '}],
#  [{'page_number': 15,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '易、通生产、通生活、通办公等，快递服务正为网购经济插上腾飞的翅膀，全天候、全覆盖的快递包裹“泛在化”时代已经'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 30,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '到来。 '},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 142,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '3、快递产业发展的格局正迎来嬗变 '},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 106,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '（1）市场竞争阶段性加剧 '},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■局部市场竞争升温：2020年第一季度，突如其来的新冠疫情给世界及我国经济社会发展带来了严重冲击，我国快递产'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '业发展也受到疫情的严重影响，快递企业普遍出现了量能不足的困难局面。第二季度以来，随着国内疫情得到有效控制，中'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '央及各级政府相继出台了“减税、降费、促消费”等一揽子稳定经济的措施，我国经济表现出了强劲的韧性，呈现出生产回升、'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '消费回补的良好态势，有力地促进线上消费异常活跃，快递企业抓住有利时机，纷纷在短时期内集中回补业务量，客观上形'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '成了第二季度局部地区的市场竞争比较激烈的局面。同时，鉴于快递产业广阔的发展空间和巨大的市场机会，少部分快递企'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 470,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '业以补贴市场的方式，以较为激进的价格政策进行低价竞争、快速获量，导致广州、义乌等地区的快递单价下行明显。 '},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■行业环境环比乐观：在市场经济和法治环境下，有效的资源最终会被优化配置，企业最终要回归“量本利”的经营逻辑'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '轨道，科技创新、服务品质与产品分层能力才是获得客户粘性、提升市场份额、体现企业核心竞争力的决定性因素。快递物'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 481,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '流行业的业务本质，是企业向客户提供的针对物品物理位移变化的服务履约能力，概而言之是又快、又好、又安全地配送'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '包裹，而履约过程中涉及一系列的资产工具承载、组织网络实施和服务标准保障。但是，如果企业没有经过长期的核心资'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '产投入，没有长期的科技能力积累，没有长期共生式的网络和品牌建设，没有基于时效和服务的产品分层能力，其履约能力'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '是无法通过凭空来完成的；短期的以价换量、低价竞争不过是企业与市场相互“薅羊毛”行为，更遑论甚至以远低于成本价格'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '进行拼抢客户，已经涉嫌严重扰乱市场的违法“倾销”行为，不可持续。实践证明，当业务量日益增大、补贴力度衰减乃至取'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 487,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '消、时效与服务品质可比没有优势的情景下，低价竞争者获得增量包裹的能力会明显下降，已经获取的客户也可能快速流失。 '},
#   {'page_number': 15,
#    'type': 1,
#    'bbox': (85.05000305175781, 497.1499938964844, 510.25, 724.489990234375)},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '特别是，自2020年8月份以来，疫情影响、集中补量、烧钱补贴等导致快递价格非正常性下行的诸多因素正逐步弱化或'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '消失，有效竞争者持续减少，市场格局进一步明朗，单票收入环比持续改善，成本壁垒下的护城河效应增强。根据对月度、'},
#   {'page_number': 15,
#    'type': 0,
#    'line_width': 11,
#    'x0': 529,
#    'line_size': 9.0,
#    'text': '15 '}],
#  [{'page_number': 16,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 16,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '季度市场数据的监测，我们认为，2020年第二、三季度快递行业竞争加剧属于短期现象、阶段性行为，快递行业的运行环'},
#   {'page_number': 16,
#    'type': 0,
#    'line_width': 276,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '境季度环比正在修复向好，并乐观预计2021年市场环境会不断改善。 '},
#   {'page_number': 16,
#    'type': 0,
#    'line_width': 115,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '（2）行业发展格局正在演变 '},
#   {'page_number': 16,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '■行业“马太效应”加剧：报告期，在新进入者低价竞争以及头部快递企业规模化、集约化发展优势冲击下，伴随着主动'},
#   {'page_number': 16,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '或被动式的差异化发展及越来越高的行业壁垒，部分快递企业的生产经营活动正面临困难，特别是在核心资产投入、科技创'},
#   {'page_number': 16,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '新、融资能力、管理管控、网络均衡性等方面遭遇困境，导致获取包裹的能力不足，盈利能力越来越差，经营现金流日趋紧'},
#   {'page_number': 16,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '张，网络的稳定性明显下降，生存空间持续萎缩。特别是“11.11”、“12.12”、“年货节”等业务旺季，既严峻考验快递企业的'},
#   {'page_number': 16,
#    'type': 0,
#    'line_width': 487,
#    'x0': 56,
#    'line_size': 9.0,
# ...
#   {'page_number': 313,
#    'type': 0,
#    'line_width': 38,
#    'x0': 502,
#    'line_size': 9.0,
#    'text': '单位：元 '},
#   {'page_number': 313,
#    'type': 2,
#    'number': 4,
#    'bbox': (57.44117774215399,
#     444.76798248291016,
#     534.6011368887765,
#     678.8199615478516),
#    'text': [['', '', '', '', '占其他应收款期末', ''],
#     ['单位名称', '款项的性质', '期末余额', '账龄', None, '坏账准备期末余额'],
#     [None, None, None, None, '余额合计数的比例', None],
#     ['', '', '', '', None, ''],
#     ['宁波梅山保税港区福', '合并范围内关联方', '', '', '', ''],
#     [None, None, '932,350,000.00', '1-3 年', '62.93%', ''],
#     ['杉投资有限公司', '往来款', None, None, None, None],
#     [None, None, '', '', '', ''],
#     ['上海韵毅实业有限公', '合并范围内关联方', '', '', '', ''],
#     [None, None, '189,032,000.00', '1 年以内', '12.76%', ''],
#     ['司', '往来款', None, None, None, None],
#     [None, None, '', '', '', ''],
#     ['上海韵达货运有限公', '合并范围内关联方', '', '', '', ''],
#     [None, None, '170,374,416.59', '1 年以内', '11.50%', ''],
#     ['司', '往来', None, None, None, None],
#     [None, None, '', '', '', ''],
#     ['宁波梅山保税港区伟', '合并范围内关联方', '', '', '', ''],
#     [None, None, '110,900,320.00', '1-3 年', '7.49%', ''],
#     ['仕投资有限公司', '往来款', None, None, None, None],
#     [None, None, '', '', '', ''],
#     ['上海韵达供应链管理', '合并范围内关联方', '', '', '', ''],
#     [None, None, '54,271,863.81', '1-3 年', '3.66%', ''],
#     ['有限公司', '往来款', None, None, None, None],
#     [None, None, '', '', '', ''],
#     ['合计', '--', '1,456,928,600.40', '--', '98.34%', '']]},
#   {'page_number': 313,
#    'type': 0,
#    'line_width': 135,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '6）涉及政府补助的应收款项 '},
#   {'page_number': 313,
#    'type': 0,
#    'line_width': 38,
#    'x0': 502,
#    'line_size': 9.0,
#    'text': '单位：元 '},
#   {'page_number': 313,
#    'type': 2,
#    'number': 5,
#    'bbox': (57.44117774215399,
#     743.0378085049716,
#     534.6011368887765,
#     762.5541520552201),
#    'text': [['单位名称', '政府补助项目名称', '期末余额', '期末账龄', '预计收取的时间、金额']]},
#   {'page_number': 313,
#    'type': 0,
#    'line_width': 15,
#    'x0': 525,
#    'line_size': 9.0,
#    'text': '313 '}],
#  [{'page_number': 314,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 314,
#    'type': 2,
#    'number': 0,
#    'bbox': (57.4712740464644,
#     72.35797119140625,
#     534.720309864391,
#     90.25997924804688),
#    'text': [['', '', '', '', '及依据']]},
#   {'page_number': 314,
#    'type': 0,
#    'line_width': 208,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '7）因金融资产转移而终止确认的其他应收款 '},
#   {'page_number': 314,
#    'type': 0,
#    'line_width': 251,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '8）转移其他应收款且继续涉入形成的资产、负债金额 '},
#   {'page_number': 314,
#    'type': 0,
#    'line_width': 47,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '其他说明： '},
#   {'page_number': 314,
#    'type': 0,
#    'line_width': 82,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '3、长期股权投资 '},
#   {'page_number': 314,
#    'type': 0,
#    'line_width': 38,
#    'x0': 502,
#    'line_size': 9.0,
#    'text': '单位：元 '},
#   {'page_number': 314,
#    'type': 2,
#    'number': 1,
#    'bbox': (57.4712740464644,
#     246.14000447591147,
#     543.4949920654296,
#     326.34999084472656),
#    'text': [['', '期末余额', None, None, '期初余额', None, None],
#     ['项目', None, None, None, None, None, None],
#     [None, '账面余额', '减值准备', '账面价值', '账面余额', '减值准备', '账面价值'],
#     ['', None, None, None, None, None, None],
#     ['对子公司投资',
#      '21,988,000,000.00',
#      '',
#      '21,988,000,000.00',
#      '21,456,000,000.00',
#      '',
#      '21,456,000,000.00'],
#     ['合计',
#      '21,988,000,000.00',
#      '',
#      '21,988,000,000.00',
#      '21,456,000,000.00',
#      '',
#      '21,456,000,000.00']]},
#   {'page_number': 314,
#    'type': 0,
#    'line_width': 92,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '（1）对子公司投资 '},
#   {'page_number': 314,
#    'type': 0,
#    'line_width': 38,
#    'x0': 502,
#    'line_size': 9.0,
#    'text': '单位：元 '},
#   {'page_number': 314,
#    'type': 2,
#    'number': 2,
#    'bbox': (57.4712740464644,
#     391.2269075833834,
#     534.720309864391,
#     762.8436514047476),
#    'text': [['', '期初余额(账面价', '本期增减变动', None, None, None, '期末余额(账面价', '减值准备'],
#     ['被投资单位', None, None, None, None, None, None, None],
#     [None, '值)', '追加投资', '减少投资', '计提减值准备', '其他', '值)', '期末余额'],
#     ['', None, None, None, None, None, None, None],
#     ['上海韵达货运', '', '', '', '', '', '', ''],
#     [None,
#      '21,335,000,000.00',
#      '352,000,000.00',
#      '',
#      '',
#      '',
#      '21,687,000,000.00',
#      ''],
#     ['有限公司', None, None, None, None, None, None, None],
#     [None, '', '', '', '', '', '', ''],
#     ['宁波梅山保税', '', '', '', '', '', '', ''],
#     ['港区福杉投资',
#      '25,000,000.00',
#      '130,000,000.00',
#      '',
#      '',
#      '',
#      '155,000,000.00',
#      ''],
#     ['有限公司', '', '', '', '', '', '', ''],
#     ['美亿达保险经', '', '', '', '', '', '', ''],
#     [None, '55,000,000.00', '', '', '', '', '55,000,000.00', ''],
#     ['纪有限公司', None, None, None, None, None, None, None],
#     [None, '', '', '', '', '', '', ''],
#     ['上海韵毅实业', '', '', '', '', '', '', ''],
#     [None, '', '50,000,000.00', '', '', '', '50,000,000.00', ''],
#     ['有限公司', None, None, None, None, None, None, None],
#     [None, '', '', '', '', '', '', ''],
#     ['上海韵达供应', '', '', '', '', '', '', ''],
#     ['链管理有限公', '17,000,000.00', '', '', '', '', '17,000,000.00', ''],
#     ['司', '', '', '', '', '', '', ''],
#     ['上海韵达国际', '', '', '', '', '', '', ''],
#     ['货运代理有限', '19,000,000.00', '', '', '', '', '19,000,000.00', ''],
#     ['公司', '', '', '', '', '', '', ''],
#     ['宁波梅山保税', '', '', '', '', '', '', ''],
#     ['港区伟仕投资', '5,000,000.00', '', '', '', '', '5,000,000.00', ''],
#     ['有限公司', '', '', '', '', '', '', ''],
#     ['合计',
#      '21,456,000,000.00',
#      '532,000,000.00',
#      '',
#      '',
#      '',
#      '21,988,000,000.00',
#      '']]},
#   {'page_number': 314,
#    'type': 0,
#    'line_width': 15,
#    'x0': 525,
#    'line_size': 9.0,
#    'text': '314 '}],
#  [{'page_number': 315,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 315,
#    'type': 0,
#    'line_width': 135,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '（2）对联营、合营企业投资 '},
#   {'page_number': 315,
#    'type': 0,
#    'line_width': 38,
#    'x0': 502,
#    'line_size': 9.0,
#    'text': '单位：元 '},
#   {'page_number': 315,
#    'type': 2,
#    'number': 0,
#    'bbox': (57.34800122578939,
#     120.6199951171875,
#     534.5783961902965,
#     231.97998046875),
#    'text': [['',
#      '',
#      '本期增减变动',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      '',
#      ''],
#     [None,
#      '期初余额',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      '期末余额',
#      None],
#     [None, None, '', '', '权益法下', '', '', '宣告发放', '', '', None, '减值准备'],
#     ['投资单位',
#      '(账面价',
#      None,
#      None,
#      None,
#      '其他综合',
#      '其他权益',
#      None,
#      '计提减值',
#      None,
#      '(账面价',
#      None],
#     [None,
#      None,
#      '追加投资',
#      '减少投资',
#      '确认的投',
#      None,
#      None,
#      '现金股利',
#      None,
#      '其他',
#      None,
#      '期末余额'],
#     ['', '值)', None, None, None, '收益调整', '变动', None, '准备', None, '值)', None],
#     [None, None, '', '', '资损益', None, None, '或利润', None, '', None, ''],
#     [None, '', None, None, None, '', '', None, '', None, '', None],
#     ['一、合营企业',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['二、联营企业',
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None]]},
#   {'page_number': 315,
#    'type': 0,
#    'line_width': 71,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '（3）其他说明 '},
#   {'page_number': 315,
#    'type': 0,
#    'line_width': 113,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '4、营业收入和营业成本 '},
#   {'page_number': 315,
#    'type': 0,
#    'line_width': 38,
#    'x0': 502,
#    'line_size': 9.0,
#    'text': '单位：元 '},
#   {'page_number': 315,
#    'type': 2,
#    'number': 1,
#    'bbox': (57.34800122578939,
#     326.69000244140625,
#     534.5783961902965,
#     406.84998321533203),
#    'text': [['', '本期发生额', None, '上期发生额', None],
#     ['项目', None, None, None, None],
#     [None, '收入', '成本', '收入', '成本'],
#     ['', None, None, None, None],
#     ['其他业务', '35,826,967.68', '29,368,191.78', '', ''],
#     ['合计', '35,826,967.68', '29,368,191.78', '', '']]},
#   {'page_number': 315,
#    'type': 0,
#    'line_width': 61,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '5、投资收益 '},
#   {'page_number': 315,
#    'type': 0,
#    'line_width': 38,
#    'x0': 502,
#    'line_size': 9.0,
#    'text': '单位：元 '},
#   {'page_number': 315,
#    'type': 2,
#    'number': 2,
#    'bbox': (57.34800122578939,
#     470.8899841308594,
#     534.5783961902965,
#     571.2099609375),
#    'text': [['项目', '本期发生额', '上期发生额'],
#     ['成本法核算的长期股权投资收益', '500,000,000.00', '600,000,000.00'],
#     ['处置长期股权投资产生的投资收益', '', '1,050,000.00'],
#     ['处置交易性金融资产取得的投资收益', '4,892,090.99', '26,597,971.56'],
#     ['合计', '504,892,090.99', '627,647,971.56']]},
#   {'page_number': 315,
#    'type': 0,
#    'line_width': 40,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '6、其他 '},
#   {'page_number': 315,
#    'type': 0,
#    'line_width': 88,
#    'x0': 56,
#    'line_size': 12.0,
#    'text': '十八、补充资料 '},
#   {'page_number': 315,
#    'type': 0,
#    'line_width': 135,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '1、当期非经常性损益明细表 '},
#   {'page_number': 315,
#    'type': 0,
#    'line_width': 76,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '√ 适用 □ 不适用  '},
#   {'page_number': 315,
#    'type': 0,
#    'line_width': 38,
#    'x0': 502,
#    'line_size': 9.0,
#    'text': '单位：元 '},
#   {'page_number': 315,
#    'type': 2,
#    'number': 3,
#    'bbox': (57.34800122578939,
#     714.0999755859375,
#     534.5783961902965,
#     754.0559997558594),
#    'text': [['项目', '金额', '说明'],
#     ['非流动资产处置损益', '-1,588,942.22', '主要系非流动资产毁损报废损失所致']]},
#   {'page_number': 315,
#    'type': 0,
#    'line_width': 15,
#    'x0': 525,
#    'line_size': 9.0,
#    'text': '315 '}],
#  [{'page_number': 316,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 316,
#    'type': 2,
#    'number': 0,
#    'bbox': (57.54000140250997,
#     72.35931396484375,
#     534.584036393599,
#     388.96997833251953),
#    'text': [['计入当期损益的政府补助（与企业业务密', '', ''],
#     ['切相关，按照国家统一标准定额或定量享', '88,951,356.42', ''],
#     ['受的政府补助除外）', '', ''],
#     ['计入当期损益的对非金融企业收取的资金', '', ''],
#     [None, '4,246,851.27', ''],
#     ['占用费', None, None],
#     [None, '', ''],
#     ['与公司正常经营业务无关的或有事项产生', '', ''],
#     [None, '-3,523,625.22', '未决诉讼'],
#     ['的损益', None, None],
#     [None, '', ''],
#     ['除同公司正常经营业务相关的有效套期保', '', ''],
#     ['值业务外，持有交易性金融资产、衍生金', None, None],
#     ['融资产、交易性金融负债、衍生金融负债', None, None],
#     ['产生的公允价值变动损益，以及处置交易', '172,719,440.19', ''],
#     ['性金融资产、衍生金融资产、交易性金融', '', ''],
#     ['负债、衍生金融负债和其他债权投资取得', None, None],
#     ['的投资收益', None, None],
#     ['除上述各项之外的其他营业外收入和支出', '-6,350,013.88', ''],
#     ['减：所得税影响额', '61,150,246.86', ''],
#     ['少数股东权益影响额', '-1,424,139.19', ''],
#     ['合计', '194,728,958.89', '--']]},
#   {'page_number': 316,
#    'type': 0,
#    'line_width': 464,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '对公司根据《公开发行证券的公司信息披露解释性公告第 1 号——非经常性损益》定义界定的非经常性损益项目，以及'},
#   {'page_number': 316,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '把《公开发行证券的公司信息披露解释性公告第 1 号——非经常性损益》中列举的非经常性损益项目界定为经常性损益的项'},
#   {'page_number': 316,
#    'type': 0,
#    'line_width': 74,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '目，应说明原因。 '},
#   {'page_number': 316,
#    'type': 0,
#    'line_width': 76,
#    'x0': 74,
#    'line_size': 9.0,
#    'text': '□ 适用 √ 不适用  '},
#   {'page_number': 316,
#    'type': 0,
#    'line_width': 135,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '2、净资产收益率及每股收益 '},
#   {'page_number': 316,
#    'type': 2,
#    'number': 1,
#    'bbox': (57.54000140250997,
#     532.989990234375,
#     534.584036393599,
#     628.7799987792969),
#    'text': [['', '', '每股收益', None],
#     ['报告期利润', '加权平均净资产收益率', None, None],
#     [None, None, '基本每股收益（元/股）', '稀释每股收益（元/股）'],
#     ['', '', None, None],
#     ['归属于公司普通股股东的净利润', '10.09%', '0.48', '0.48'],
#     ['扣除非经常性损益后归属于公司', '', '', ''],
#     [None, '8.69%', '0.42', '0.42'],
#     ['普通股股东的净利润', None, None, None],
#     [None, '', '', '']]},
#   {'page_number': 316,
#    'type': 0,
#    'line_width': 166,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '3、境内外会计准则下会计数据差异 '},
#   {'page_number': 316,
#    'type': 0,
#    'line_width': 419,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '（1）同时按照国际会计准则与按中国会计准则披露的财务报告中净利润和净资产差异情况 '},
#   {'page_number': 316,
#    'type': 0,
#    'line_width': 76,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '□ 适用 √ 不适用  '},
#   {'page_number': 316,
#    'type': 0,
#    'line_width': 15,
#    'x0': 525,
#    'line_size': 9.0,
#    'text': '316 '}],
#  [{'page_number': 317,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 317,
#    'type': 0,
#    'line_width': 419,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '（2）同时按照境外会计准则与按中国会计准则披露的财务报告中净利润和净资产差异情况 '},
#   {'page_number': 317,
#    'type': 0,
#    'line_width': 76,
#    'x0': 56,
#    'line_size': 9.0,
#    'text': '□ 适用 √ 不适用  '},
#   {'page_number': 317,
#    'type': 0,
#    'line_width': 482,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '（3）境内外会计准则下会计数据差异原因说明，对已经境外审计机构审计的数据进行差异调节的，应注'},
#   {'page_number': 317,
#    'type': 0,
#    'line_width': 98,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '明该境外机构的名称 '},
#   {'page_number': 317,
#    'type': 0,
#    'line_width': 40,
#    'x0': 56,
#    'line_size': 10.56,
#    'text': '4、其他 '},
#   {'page_number': 317,
#    'type': 0,
#    'line_width': 15,
#    'x0': 525,
#    'line_size': 9.0,
#    'text': '317 '}],
#  [{'page_number': 318,
#    'type': 0,
#    'line_width': 177,
#    'x0': 363,
#    'line_size': 9.0,
#    'text': '韵达控股股份有限公司 2020 年年度报告全文 '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 173,
#    'x0': 213,
#    'line_size': 15.96,
#    'text': '第十三节 备查文件目录 '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 467,
#    'x0': 80,
#    'line_size': 12.0,
#    'text': '一、载有公司法定代表人聂腾云先生、主管会计工作负责人谢万涛先生、会计机构负责人'},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 186,
#    'x0': 56,
#    'line_size': 12.0,
#    'text': '刘辉先生签名并盖章的财务报表。 '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 378,
#    'x0': 80,
#    'line_size': 12.0,
#    'text': '二、载有会计师事务所签章、注册会计师签名并盖章的审计报告原件。 '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 467,
#    'x0': 80,
#    'line_size': 12.0,
#    'text': '三、报告期内在中国证监会指定网站上、指定报纸上公开披露过的所有公司文件正本及公'},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 54,
#    'x0': 56,
#    'line_size': 12.0,
#    'text': '告原稿。 '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 318,
#    'x0': 80,
#    'line_size': 12.0,
#    'text': '四、载有公司法定代表人签名的2020年年度报告文件原件。 '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 114,
#    'x0': 80,
#    'line_size': 12.0,
#    'text': '五、其他有关资料。 '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 6,
#    'x0': 80,
#    'line_size': 12.0,
#    'text': ' '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 258,
#    'x0': 80,
#    'line_size': 12.0,
#    'text': '以上备查文件的备置地点：公司董事会办公室。 '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 6,
#    'x0': 80,
#    'line_size': 12.0,
#    'text': ' '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 6,
#    'x0': 80,
#    'line_size': 12.0,
#    'text': ' '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 6,
#    'x0': 80,
#    'line_size': 12.0,
#    'text': ' '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 138,
#    'x0': 418,
#    'line_size': 12.0,
#    'text': '韵达控股股份有限公司    '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 3,
#    'x0': 538,
#    'line_size': 12.0,
#    'text': ' '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 121,
#    'x0': 430,
#    'line_size': 12.0,
#    'text': '法定代表人：聂腾云   '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 3,
#    'x0': 538,
#    'line_size': 12.0,
#    'text': ' '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 81,
#    'x0': 460,
#    'line_size': 12.0,
#    'text': '2020年4月30日 '},
#   {'page_number': 318,
#    'type': 0,
#    'line_width': 15,
#    'x0': 525,
#    'line_size': 9.0,
#    'text': '318 '}]]

# %%
from collections import Counter
def get_constant(lines_width, x0_list, font_size_list, text_list, page_info):
	line_width_mode = Counter(lines_width).most_common(1)[0][0]
	x0_mode = Counter(x0_list).most_common(1)[0][0]
	font_size_cunt = Counter(font_size_list)
	text_list_count = Counter(text_list)
	duplicate_rows = []
	for i, j in text_list_count.items():
		if j >= 5:
			duplicate_rows.append(i)
	
	effective_font_size = []
	for i, j in font_size_cunt.items():
		if j >= 1:
			effective_font_size.append(i)
	font_size_mode = font_size_cunt.most_common(1)[0][0]
	print(f"""
	line width : {line_width_mode}
	x0 : {x0_mode}
	font size : {font_size_mode}
	duplicate rows : {duplicate_rows}
	effective font size : {effective_font_size}
	""")
	
	return line_width_mode, x0_mode, font_size_mode, duplicate_rows, effective_font_size

# %%
line_width_mode, x0_mode, font_size_mode, duplicate_rows, effective_font_size = get_constant(lines_width, x0_list,
	                                                                                             font_size_list,
	                                                                                             text_list, pdf_info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 line_width_mode, x0_mode, font_size_mode, duplicate_rows, effective_font_size = get_constant(lines_width, x0_list,
#       2 	                                                                                             font_size_list,
#       3 	                                                                                             text_list, pdf_info)
#
# NameError: name 'get_constant' is not defined

# %%
def get_line_type(pdf_info, line_width_mode, x0_mode, font_size_mode, duplicate_rows, effective_font_size):
	new_pdf_info1 = []
	directory_text = ""
	directory_page_number = 0
	directory_flag = False
	directory_line_width = []
	for i, page_info in enumerate(pdf_info):
		page_text1 = []
		for j, line_info in enumerate(page_info):
			line_type = line_info["type"]
			page_number = line_info["page_number"]
			if line_type == 0:
				line_text = line_info["text"]
				line_width = line_info["line_width"]
				line_size = line_info["line_size"]
				line_x0 = line_info["x0"]
				line_description = ""
				line_text_flag = -1
				if directory_flag and page_number == directory_page_number:
					if line_width not in directory_line_width:
						directory_line_width.append(line_width)
					
					line_description = "directory"
					directory_text += "\n" + line_text
					page_text1.append({"page_number": page_number, "text": line_text, "type": line_description,
					                   "text_flag": line_text_flag})
					continue
				
				elif directory_flag and page_number <= directory_page_number + 2:
					if line_width in directory_line_width:
						directory_text += "\n" + line_text
						line_description = "directory"
						page_text1.append({"page_number": page_number, "text": line_text, "type": line_description,
						                   "text_flag": line_text_flag})
						continue
					else:
						directory_flag = False
				else:
					directory_flag = False
				
				if line_text in duplicate_rows or line_size not in effective_font_size:
					continue
				elif "目录" in line_text:
					directory_flag = True
					directory_text += line_text
					directory_page_number = page_number
					line_description = "directory"
				elif abs(line_x0 - x0_mode) == 0:
					if abs(line_width - line_width_mode) <= line_size * 3:
						line_description = "text"
						line_text_flag = 2
					elif line_text in directory_text:
						line_description = "title"
					elif "." in line_text and "。" not in line_text and "；" not in line_text:
						line_description = "title"
					elif "。" in line_text or "；" in line_text or "：" in line_text:
						line_description = "text"
						line_text_flag = 3
					else:
						line_description = "text"
						line_text_flag = 3
				elif 0 < abs(line_x0 - x0_mode) <= line_size * 3:
					if abs(line_width - line_width_mode) <= line_size * 3:
						line_description = "text"
						line_text_flag = 1
					else:
						line_description = "title"
				elif abs(line_x0 - x0_mode) >= line_size * 3 and line_width > 2 * line_size:
					if "图" in line_text:
						line_description = "image name"
					elif "表" in line_text:
						line_description = "table name"
					else:
						line_description = "clutter"
				else:
					if line_width < 2 * line_size:
						continue
					else:
						line_description = "clutter"
				if line_description == "":
					print(line_info)
				page_text1.append({"page_number": page_number, "text": line_text, "type": line_description,
				                   "text_flag": line_text_flag})
			elif line_type == 1:
				page_text1.append({"page_number": page_number, "text": "", "type": "image", "text_flag": -1})
			elif line_type == 2:
				if len(page_text1) == 0:
					line_text_flag = 2
				else:
					line_text_flag = 1
				page_text1.append({"page_number": page_number, "text": line_info["text"], "type": "table",
				                   "text_flag": line_text_flag})
		new_pdf_info1 += page_text1
	return new_pdf_info1

# %%
new_pdf_info1 = get_line_type(pdf_info, line_width_mode, x0_mode, font_size_mode, duplicate_rows,
                                effective_font_size, )

# %%
new_pdf_info1
# Out:
# [{'page_number': 1, 'text': '韵达控股股份有限公司 ', 'type': 'clutter', 'text_flag': -1},
#  {'page_number': 1, 'text': '2020 年年度报告 ', 'type': 'clutter', 'text_flag': -1},
#  {'page_number': 1,
#   'text': '2021 年 04 月 ',
#   'type': 'clutter',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '第一节 重要提示、目录和释义 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '公司董事会、监事会及董事、监事、高级管理人员保证年度报告内容的真',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '实、准确、完整，不存在虚假记载、误导性陈述或重大遗漏，并承担个别和连',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2, 'text': '带的法律责任。 ', 'type': 'directory', 'text_flag': -1},
#  {'page_number': 2,
#   'text': '公司负责人聂腾云、主管会计工作负责人谢万涛及会计机构负责人(会计主',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '管人员)刘辉声明：保证本年度报告中财务报告的真实、准确、完整。 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '所有董事均已出席了审议本报告的董事会会议。 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '本报告中涉及的未来发展规划及经营目标相关的前瞻性陈述，属于计划性',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '事项，不构成公司对投资者的实质承诺，敬请投资者理性投资，注意投资风险。 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '公司需遵守《深圳证券交易所行业信息披露指引第 9 号—上市公司从事快',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '递服务业务》的披露要求。 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '公司在本年度报告中详细阐述了未来可能发生的有关风险因素及对策，详',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '见“第四节经营情况讨论与分析”之“九、公司未来发展的展望”中的“可能',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '面临的风险及应对措施”，敬请投资者予以关注。 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '公司经本次董事会审议通过的利润分配预案为：以利润分配实施时股权登',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '记日的公司总股本为基数，向全体股东每 10 股派发现金红利 0.49 元（含税），',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2,
#   'text': '送红股 0 股（含税），不以公积金转增股本。 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 2, 'text': '2 ', 'type': 'directory', 'text_flag': -1},
#  {'page_number': 3, 'text': '目录 ', 'type': 'directory', 'text_flag': -1},
#  {'page_number': 3,
#   'text': '第一节 重要提示、目录和释义 ..................................................................................................................... 2 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 3,
#   'text': '第二节 公司简介和主要财务指标 ................................................................................................................. 5 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 3,
#   'text': '第三节 公司业务概要 ..................................................................................................................................... 9 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 3,
#   'text': '第四节 经营情况讨论与分析 ....................................................................................................................... 34 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 3,
#   'text': '第五节 重要事项 ........................................................................................................................................... 73 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 3,
#   'text': '第六节 股份变动及股东情况 ....................................................................................................................... 96 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 3,
#   'text': '第七节 优先股相关情况 ............................................................................................................................. 103 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 3,
#   'text': '第八节 可转换公司债券相关情况 ............................................................................................................. 104 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 3,
#   'text': '第九节 董事、监事、高级管理人员和员工情况 ..................................................................................... 105 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 3,
#   'text': '第十节 公司治理 .......................................................................................................................................... 115 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 3,
#   'text': '第十一节 公司债券相关情况 ..................................................................................................................... 123 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 3,
#   'text': '第十二节 财务报告 ..................................................................................................................................... 124 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 3,
#   'text': '第十三节 备查文件目录 ............................................................................................................................. 318 ',
#   'type': 'directory',
#   'text_flag': -1},
#  {'page_number': 3, 'text': '3 ', 'type': 'directory', 'text_flag': -1},
#  {'page_number': 4, 'text': '释义 ', 'type': 'clutter', 'text_flag': -1},
#  {'page_number': 4,
#   'text': [['释义项', '指', '释义内容'],
#    ['报告期', '指', '2020 年 1 月 1 日至 2020 年 12 月 31 日'],
#    ['上年同期', '指', '2019 年 1 月 1 日至 2019 年 12 月 31 日'],
#    ['公司/本公司/韵达/韵达股份/韵达控股', '指', '韵达控股股份有限公司'],
#    ['韵达货运', '指', '上海韵达货运有限公司'],
#    ['上海罗颉思', '指', '上海罗颉思投资管理有限公司'],
#    ['上海丰科', '指', '上海丰科企业管理合伙企业（有限合伙）'],
#    ['桐庐韵嘉', '指', '桐庐韵嘉投资管理合伙企业（有限合伙）'],
#    ['桐庐韵科', '指', '桐庐韵科投资管理合伙企业（有限合伙）'],
#    ['上海太富祥川', '指', '上海太富祥川股权投资基金合伙企业（有限合伙）'],
#    ['宁波招银', '指', '宁波招银成长拾号投资合伙企业（有限合伙）'],
#    ['深圳富海臻界', '指', '深圳富海臻界物流二号投资企业（有限合伙）'],
#    ['宁波中钰', '指', '宁波中钰股权投资合伙企业（有限合伙）'],
#    ['宁波云晖景盛', '指', '宁波云晖景盛投资管理合伙企业（有限合伙）'],
#    ['福杉投资', '指', '宁波梅山保税港区福杉投资有限公司'],
#    ['东普科技', '指', '上海东普信息科技有限公司'],
#    ['', '', '宁波新海电气股份有限公司，为韵达控股股份有限公司的前身，于 2017 年'],
#    ['新海股份', '指', None],
#    [None, None, '1 月更名为韵达控股股份有限公司'],
#    ['', '', None],
#    ['', '', '本公司前身宁波新海电气股份有限公司以截至置出资产评估基准日全部资'],
#    [None, None, '产及负债与上海韵达货运有限公司全体股东持有的上海韵达货运有限公司'],
#    ['重大资产重组', '指', None],
#    [None, None, '100%股权的等值部分进行置换，并以发行股份的方式自上海韵达货运有限'],
#    ['', '', None],
#    [None, None, '公司全体股东处购买置入资产与置出资产差额部分'],
#    ['《公司法》', '指', '《中华人民共和国公司法》'],
#    ['《证券法》', '指', '《中华人民共和国证券法》'],
#    ['《公司章程》', '指', '《韵达控股股份有限公司章程》'],
#    ['深交所', '指', '深圳证券交易所'],
#    ['元、万元、亿元', '指', '人民币元、人民币万元、人民币亿元']],
#   'type': 'table',
#   'text_flag': 1},
#  {'page_number': 5,
#   'text': '第二节 公司简介和主要财务指标 ',
#   'type': 'clutter',
#   'text_flag': -1},
#  {'page_number': 5, 'text': '一、公司信息 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 5,
#   'text': [['股票简称', '韵达股份', '股票代码', '002120'],
#    ['股票上市证券交易所', '深圳证券交易所', None, None],
#    ['公司的中文名称', '韵达控股股份有限公司', None, None],
#    ['公司的中文简称', '韵达股份', None, None],
#    ['公司的外文名称（如有）', 'YUNDA Holding Co., Ltd.', None, None],
#    ['公司的外文名称缩写（如有）', 'YUNDA Corp.', None, None],
#    ['公司的法定代表人', '聂腾云', None, None],
#    ['注册地址', '浙江省慈溪市崇寿镇永清南路 8 号', None, None],
#    ['注册地址的邮政编码', '315334', None, None],
#    ['办公地址', '上海市青浦区盈港东路 6679 号', None, None],
#    ['办公地址的邮政编码', '201700', None, None],
#    ['公司网址', 'www.yundaex.com', None, None],
#    ['电子信箱', 'ir@yundaex.com', None, None]],
#   'type': 'table',
#   'text_flag': 1},
#  {'page_number': 5, 'text': '二、联系人和联系方式 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 5,
#   'text': [['', '董事会秘书', '证券事务代表'],
#    ['姓名', '符勤', '杨红波'],
#    ['联系地址', '上海市青浦区盈港东路 6679 号', '上海市青浦区盈港东路 6679 号'],
#    ['电话', '021-39296789', '021-39296789'],
#    ['传真', '021-39296863', '021-39296863'],
#    ['电子信箱', 'ir@yundaex.com', 'ir@yundaex.com']],
#   'type': 'table',
#   'text_flag': 1},
#  {'page_number': 5, 'text': '三、信息披露及备置地点 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 5,
#   'text': [['公司选定的信息披露媒体的名称', '《中国证券报》、《上海证券报》、《证券时报》、《证券日报》'],
#    ['登载年度报告的中国证监会指定网站的网址', 'www.cninfo.com.cn'],
#    ['公司年度报告备置地点', '公司董事会办公室']],
#   'type': 'table',
#   'text_flag': 1},
#  {'page_number': 6, 'text': '四、注册变更情况 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 6,
#   'text': [['组织机构代码', '91330200144745634H'],
#    ['公司上市以来主营业务的变化情况（如', ''],
#    [None, '报告期内无变更'],
#    ['有）', None],
#    [None, ''],
#    ['历次控股股东的变更情况（如有）', '报告期内无变更']],
#   'type': 'table',
#   'text_flag': 1},
#  {'page_number': 6, 'text': '五、其他有关资料 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 6, 'text': '公司聘请的会计师事务所 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 6,
#   'text': [['会计师事务所名称', '容诚会计师事务所（特殊普通合伙）'],
#    ['会计师事务所办公地址', '北京市西城区阜成门外大街 22 号 1 幢外经贸大厦 901-22 至 901-26'],
#    ['签字会计师姓名', '廖金辉、毛燕庆']],
#   'type': 'table',
#   'text_flag': 1},
#  {'page_number': 6,
#   'text': '公司聘请的报告期内履行持续督导职责的保荐机构 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 6,
#   'text': '公司聘请的报告期内履行持续督导职责的财务顾问 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 6, 'text': '六、主要会计数据和财务指标 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 6,
#   'text': '公司是否需追溯调整或重述以前年度会计数据 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 6,
#   'text': [['', '2020 年', '2019 年', '本年比上年增减', '2018 年'],
#    ['营业收入（元）',
#     '33,500,425,643.17',
#     '34,404,046,688.25',
#     '-2.63%',
#     '13,855,989,746.71'],
#    ['归属于上市公司股东的净利润（元）',
#     '1,404,493,896.78',
#     '2,647,196,861.81',
#     '-46.94%',
#     '2,697,993,712.88'],
#    ['归属于上市公司股东的扣除非经常性', '', '', '', ''],
#    [None,
#     '1,209,764,937.89',
#     '2,413,878,859.89',
#     '-49.88%',
#     '2,135,008,077.06'],
#    ['损益的净利润（元）', None, None, None, None],
#    [None, '', '', '', ''],
#    ['经营活动产生的现金流量净额（元）',
#     '2,183,637,598.99',
#     '5,035,636,370.68',
#     '-56.64%',
#     '3,714,468,466.28'],
#    ['基本每股收益（元/股）', '0.48', '0.91', '-47.25%', '0.95'],
#    ['稀释每股收益（元/股）', '0.48', '0.91', '-47.25%', '0.95'],
#    ['加权平均净资产收益率', '10.09%', '21.22%', '下降 11.13 个百分点', '28.84%'],
#    ['', '2020 年末', '2019 年末', '本年末比上年末增减', '2018 年末']],
#   'type': 'table',
#   'text_flag': 1},
#  {'page_number': 7,
#   'text': [['总资产（元）',
#     '29,500,766,142.95',
#     '22,496,654,773.40',
#     '31.13%',
#     '18,080,928,087.75'],
#    ['归属于上市公司股东的净资产（元）',
#     '14,377,889,835.81',
#     '13,462,844,669.99',
#     '6.80%',
#     '11,460,426,396.95']],
#   'type': 'table',
#   'text_flag': 2},
#  {'page_number': 7,
#   'text': '公司最近三个会计年度扣除非经常性损益前后净利润孰低者均为负值，且最近一年审计报告显示公司持续经营能力存在不确',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 7, 'text': '定性 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 7,
#   'text': '扣除非经常损益前后的净利润孰低者为负值 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 7,
#   'text': '七、境内外会计准则下会计数据差异 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 7,
#   'text': '1、同时按照国际会计准则与按照中国会计准则披露的财务报告中净利润和净资产差异情况 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 7,
#   'text': '公司报告期不存在按照国际会计准则与按照中国会计准则披露的财务报告中净利润和净资产差异情况。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 7,
#   'text': '2、同时按照境外会计准则与按照中国会计准则披露的财务报告中净利润和净资产差异情况 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 7,
#   'text': '公司报告期不存在按照境外会计准则与按照中国会计准则披露的财务报告中净利润和净资产差异情况。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 7, 'text': '八、分季度主要财务指标 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 7,
#   'text': [['', '第一季度', '第二季度', '第三季度', '第四季度'],
#    ['营业收入',
#     '5,624,623,279.64',
#     '8,692,997,527.33',
#     '8,769,715,836.12',
#     '10,413,089,000.08'],
#    ['归属于上市公司股东的净利润',
#     '333,972,438.02',
#     '347,027,887.18',
#     '339,015,692.76',
#     '384,477,878.82'],
#    ['归属于上市公司股东的扣除非经', '', '', '', ''],
#    [None,
#     '259,825,657.13',
#     '299,627,417.77',
#     '294,895,271.01',
#     '355,416,591.98'],
#    ['常性损益的净利润', None, None, None, None],
#    [None, '', '', '', ''],
#    ['经营活动产生的现金流量净额',
#     '-564,576,931.27',
#     '895,229,924.19',
#     '527,538,760.73',
#     '1,325,445,845.34']],
#   'type': 'table',
#   'text_flag': 1},
#  {'page_number': 7,
#   'text': '上述财务指标或其加总数是否与公司已披露季度报告、半年度报告相关财务指标存在重大差异 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 8, 'text': '九、非经常性损益项目及金额 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 8,
#   'text': [['项目', '2020 年金额', '2019 年金额', '2018 年金额', '说明'],
#    ['非流动资产处置损益（包括已计提资产减', '-1,588,942.22', '', '', '主要系非流动资产毁损报废损失所致'],
#    [None, None, '-111,884,013.87', '-58,309,553.01', None],
#    ['值准备的冲销部分）', None, None, None, None],
#    [None, None, '', '', None],
#    ['计入当期损益的政府补助（与企业业务密', '88,951,356.42', '', '', ''],
#    ['切相关，按照国家统一标准定额或定量享', None, '209,095,219.92', '62,674,185.61', None],
#    ['受的政府补助除外）', None, '', '', None],
#    ['计入当期损益的对非金融企业收取的资金', '4,246,851.27', '', '', ''],
#    [None, None, '3,990,158.50', '1,875,390.96', None],
#    ['占用费', None, None, None, None],
#    [None, None, '', '', None],
#    ['委托他人投资或管理资产的损益', '', '', '170,521,271.58', ''],
#    ['与公司正常经营业务无关的或有事项产生', '-3,523,625.22', '', '', '未决诉讼'],
#    [None, None, '762,102.07', '-1,924,548.50', None],
#    ['的损益', None, None, None, None],
#    [None, None, '', '', None],
#    ['除同公司正常经营业务相关的有效套期保', '172,719,440.19', '', '', ''],
#    ['值业务外，持有交易性金融资产、衍生金', None, None, None, None],
#    ['融资产、交易性金融负债、衍生金融负债', None, None, None, None],
#    ['产生的公允价值变动损益，以及处置交易', None, '236,876,668.90', '588,343,482.92', None],
#    ['性金融资产、衍生金融资产、交易性金融', None, '', '', None],
#    ['负债、衍生金融负债和其他债权投资取得', None, None, None, None],
#    ['的投资收益', None, None, None, None],
#    ['单独进行减值测试的应收款项、合同资产', '', '', '', ''],
#    [None, None, '1,944,324.23', '', None],
#    ['减值准备转回', None, None, None, None],
#    [None, None, '', '', None],
#    ['除上述各项之外的其他营业外收入和支出',
#     '-6,350,013.88',
#     '-12,610,374.56',
#     '-9,734,163.08',
#     ''],
#    ['减：所得税影响额', '61,150,246.86', '94,567,303.84', '188,508,563.35', ''],
#    ['少数股东权益影响额（税后）', '-1,424,139.19', '288,779.43', '1,951,867.31', ''],
#    ['合计', '194,728,958.89', '233,318,001.92', '562,985,635.82', '--']],
#   'type': 'table',
#   'text_flag': 1},
#  {'page_number': 8,
#   'text': '对公司根据《公开发行证券的公司信息披露解释性公告第 1 号——非经常性损益》定义界定的非经常性损益项目，以及把《公',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 8,
#   'text': '开发行证券的公司信息披露解释性公告第 1 号——非经常性损益》中列举的非经常性损益项目界定为经常性损益的项目，应',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 8, 'text': '说明原因 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 8,
#   'text': '公司报告期不存在将根据《公开发行证券的公司信息披露解释性公告第 1 号——非经常性损益》定义、列举的非经常性损益',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 8,
#   'text': '项目界定为经常性损益的项目的情形。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 9, 'text': '第三节 公司业务概要 ', 'type': 'clutter', 'text_flag': -1},
#  {'page_number': 9,
#   'text': '一、报告期内公司从事的主要业务 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 9,
#   'text': '公司需遵守《深圳证券交易所行业信息披露指引第 9 号——上市公司从事快递服务业务》的披露要求 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 9,
#   'text': '（一）报告期内公司从事的主要业务、产品及其用途，经营模式等 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 9, 'text': '1、公司主营业务 ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 9,
#   'text': '韵达股份是国内领先的快递综合服务提供商。公司以“韵达+”理念为引领，以科技创新、精细管理为驱动，践行“绿色快',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 9,
#   'text': '递，智领未来”的新发展观，实施“守正开放、多元协同、一超多强”的发展战略，用优秀的快递服务品质辐射周边市场、周',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 9,
#   'text': '边需求、周边产品，构建“以快递为核心，聚合周边产业、新业务、新业态协同发展”的多层次综合物流生态圈，追求“向客',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 9,
#   'text': '户提供极致的快递服务体验和无与伦比的快递时效”的发展愿景。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 9, 'text': '2、公司主要产品与服务 ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 9,
#   'text': '公司以服务实体经济为宗旨，以满足客户需求为导向，做大做强快递核心主业，巩固并不断扩大标准快递业务的品牌优',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 9,
#   'text': '势、规模优势和市场优势；同时，将优质的服务品质进行流量转化，积极实施快递业务“客户分群、产品分层”策略，大力发',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 9,
#   'text': '展菜鸟裹裹、韵达特快等高附加值时效产品，集中精力开拓韵达特快客户群；另外，用快递流量积极嫁接周边市场，陆续布',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 9,
#   'text': '局了韵达供应链、韵达国际、韵达冷链、韵达科技以及韵达末端服务、广告宣传等周边产业链，为提升国民经济运行效率、',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 9,
#   'text': '推动新经济发展、提高居民消费水平等提供基础性支撑。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 10, 'text': '', 'type': 'image', 'text_flag': -1},
#  {'page_number': 10,
#   'text': '■快递产品：标准快递、时效产品（韵达特快、裹裹寄件、当日达、次日达）等 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 10, 'text': '■同城即配：同城派送 ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 10,
#   'text': '■增值服务：代收货款、保价业务、门店调拨、签单返还、开放平台、逆向物流、隐私面单、送前电联、预约配送等 ',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 10,
#   'text': '■韵达供应链：仓配一体、仓店调拨、数据和软件服务、整体解决方案等，通过云技术形成“万仓联盟”，为上下游客户',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 10,
#   'text': '提供全方位的仓配一体化解决方案 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 10,
#   'text': '■韵达国际：标准进口&出口服务（国际专线、国际特惠、国际小包、国际重货、FBA等）、仓储（保税仓储、海外仓',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 10, 'text': '储）、转运等相关业务 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 10,
#   'text': '■韵达冷链：致力于提供冷链全流程完整的解决方案，可以提供存储、拆零、分拣、配货、包装、贴标、流通加工等仓',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 10,
#   'text': '管服务，以及干线运输、城市配送、末端配送等一体化冷链物流服务 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 10, 'text': '3、公司快递经营模式 ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 10,
#   'text': '公司采用“枢纽中转自营与末端网络加盟”的快递经营模式。自营方面，所有枢纽转运中心的设立、投资、运营、管理均',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 10,
#   'text': '由公司总部负责，实现对核心资源、干线网络及服务品质的有效控制力；加盟方面，全网的收派两端、业务开拓和客户体验',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 10,
#   'text': '主要由具备快递经营许可、资质优良的加盟商提供服务，最终形成“枢纽转运中心和干线网络自营、终端揽派加盟相结合”',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 10, 'text': '', 'type': 'image', 'text_flag': -1},
#  {'page_number': 11,
#   'text': '的网络化、平台化、扁平化运营模式。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 11,
#   'text': '（二）行业发展阶段、周期性特点以及公司所处行业地位 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 11,
#   'text': '1、快递产业持续获享政策红利支持 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 11,
#   'text': '快递物流产业是联结第一、第二产业以及国际贸易的新型服务业，一端连着供给侧，一端连着需求侧，具有经济先导、',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 11,
#   'text': '民生保障等特性，在提升经济资源配置效率、推动电子商务经济发展、降低全社会物流总成本、提高国民生活水平等方面发',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 11,
#   'text': '挥着战略支撑作用。同时，快递产业还是实践“大众创业、万众创新”、吸纳就业的重要载体，是“众人做事，集众智集众力，',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 11,
#   'text': '众人共享”的好业态、好模式，快递小哥是“美好生活的创造者、守护者”。在新时代背景下，快递产业作为新经济、新服务、',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 11,
#   'text': '新业态的代表，当前正处于信息化、数字化、智能化、智慧化之难得的战略发展机遇期，备受政策红利支持，党和政府及相',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 11, 'text': '关监管部门颁布了诸多政策。 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 11,
#   'text': '继2009年修订《中华人民共和国邮政法》并首次从法律层面明确快递行业的法律地位之后，2018年5月1日实施的《快递',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 11,
#   'text': '暂行条例》又将“持续推动快递业健康发展”、“保障快递安全”、“保护用户合法权益”作为促进我国快递业发展和治理体系现',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 11,
#   'text': '代化的核心主题，保障我国快递业实现由大到强的转变，促进高质量的发展。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 11,
#   'text': '国家邮政局发布的《快递业发展“十三五”规划》指出，2020年我国将基本建成普惠城乡、技术先进、服务优质、安全高',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 11,
#   'text': '效、绿色节能的快递服务体系，形成覆盖全国、联通国际的服务网站。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 11,
#   'text': '2020年2月5日，国务院常务会议提出，对运输防控重点物资和提供公共交通、生活服务、邮政快递收入免征增值税，疫',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 11,
#   'text': '情税费优惠政策期限延至2020年12月31日；交通运输部发布了《关于新冠肺炎疫情防控期间免收收费公路车辆通行费的通知》，',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 11,
#   'text': '交通运输部关于《统筹推进疫情防控和经济社会发展交通运输工作的实施意见》中明确指出要全力确保物流畅通。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 11,
#   'text': '2020年3月3日，李克强总理主持召开国务院常务会议，指出推动交通运输、快递等物流业加快复工复产，实现稳定发展。',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 11,
#   'text': '各地要对邮政和各种所有制快递企业给予一视同仁的通行便利，打破乡村、社区“最后一公里”投递障碍。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 11,
#   'text': '2020年4月，国家邮政局、工业和信息化部印发了《关于促进快递业与制造业深度融合发展的意见》，指出要探索建立',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 11,
#   'text': '符合我国国情的物流业制造业融合发展模式，推动快递业提升服务能力，健全产品体系，创新发展供应链，构建与制造业高',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 11,
#   'text': '质量发展相适应的快递物流服务体系，形成快递业与制造业深度融合的发展格局。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 11,
#   'text': '2020年5月，国家发展改革委和交通运输部联合发布了《关于进一步降低物流成本的实施意见》，指出加快发展智慧物',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 11,
#   'text': '流，积极发展绿色物流。并且要深化关键环节改革，降低物流制度成本。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 11,
#   'text': '2020年8月，交通运输部《关于推动交通运输领域新型基础设施建设的指导意见》中明确了“打造融合高效的智慧交通基',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 11,
#   'text': '础设施”的任务，对于“智慧邮政”方面要推广邮政快递转运中心自动化分拣设备、机械化装卸设备。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 11,
#   'text': '2020年9月，国务院办公厅发布了《关于以新业态新模式引领新型消费加快发展的意见》指出 “加快建设国际寄递物流',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 11,
#   'text': '服务体系，统筹推进国际物流供应链建设，降低物流成本。”国家发展改革委、工业和信息化部等14部门联合印发了《推动',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 11,
#   'text': '物流业制造业深度融合创新发展实施方案》，提出到2025年，物流业在促进实体经济降本增效、供应链协同、制造业高质量',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 11,
#   'text': '发展等方面作用显著增强，要“探索建立符合我国国情的物流业制造业融合发展模式”。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 12,
#   'text': '我国最新发布的“十四五规划”和二〇三五年远景目标指出，要加快发展现代物流等服务业，构建现代物流体系，加快推',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 12,
#   'text': '进服务业数字化。中国物流行业要重点着力于智慧物流的深化应用、物流供应链模式创新、可持续发展的绿色低碳物流等方',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 12,
#   'text': '面的建设，推动中国物流行业进入转型升级新时期。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 12,
#   'text': '2、快递包裹“泛在化”时代已经到来 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 12,
#   'text': '（1）移动互联网技术进入全民化时代 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 12,
#   'text': '互联网让人类社交方式突破了时空限制，开创了社交新纪元。在互联网基础设施建设、移动终端设备普及和政府“提速',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 12,
#   'text': '降费”红利政策等因素积极推动下，我国网络用户、网络购物用户、网络支付用户三项数据连续多年保持着持续增长态势。 ',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 12,
#   'text': '■网络用户方面：据中国互联网络信息中心发布的《第47次中国互联网络发展状况统计报告》',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 12,
#   'text': '（以下简称“CNNIC报告”），',
#   'type': 'clutter',
#   'text_flag': -1},
#  {'page_number': 12,
#   'text': '截至2020年12月，我国网民规模高达9.89亿，较2020年3月增长8540万，互联网普及率达70.4%，较一季度末提升近6个百分',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 12,
#   'text': '点；我国手机网民规模达9.86亿，较2020年3月增长8885万，网民使用手机上网的比例达99.7%，较一季度末提升0.4个百分',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 12,
#   'text': '点；农村网民规模达3.09亿，占网民总体的31.3%，较2020年3月增长5471万，城镇网民规模达6.8亿，占网民总体的68.7%，',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 12,
#   'text': '较2020年3月增长3069万。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 12,
#   'text': '■网络支付方面：截至2020年12月，我国网络支付用户规模达8.54亿，较2020年3月增长8636万，占网民整体的86.4%；',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 12,
#   'text': '手机网络支付用户规模达8.53亿，较2020年3月增长8744万，占手机网民的86.5%。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 12,
#   'text': '■网购用户方面：截至2020年12月，我国网络购物用户规模达7.82亿，较2020年3月增长7215万，占网民整体的79.1%；',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 12,
#   'text': '手机网络购物用户规模达7.81亿，较2020年3月增长7309万，占手机网民的79.2%。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 12,
#   'text': '近年来，我国网络扶贫行动向纵深发展取得实质进展，带动农村特别是边远贫困地区人口加速转网化，报告期农村网民',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 12,
#   'text': '的增长远高于城镇网民增长数量。乐观预计，在移动互联网全民化浪潮及人均可支配收入持续增长背景下，我国网络用户、',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 12,
#   'text': '网络购物用户还有较大的渗透空间，移动互联网技术的应用已进入全民化时代，超过10亿人口的网络用户将长期释放庞大的',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 12, 'text': '网购市场红利。 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 12, 'text': '', 'type': 'image', 'text_flag': -1},
#  {'page_number': 12,
#   'text': '（2）立体式网购经济正加速释放增量包裹 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 13,
#   'text': '■电商平台多元化：近年来，我国移动互联网与内需消费深度融合，电子商务经济继续保持着蓬勃的发展态势，以创新',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 13,
#   'text': '的营销方式和商业模式实现流量变现，呈现出了全新的、平台多元化的网络购物新生态。一方面，淘宝、京东商城、苏宁易',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '购等第一代大型综合电商平台稳健发展，在用户流量、全品类交易、渠道下沉、培育增量GMV等方面持续迭代；另一方面，',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '以拼多多、微商等为代表的第二代新型电商平台，一是没有购物车，二是省去对消费者网购习惯的培育成本，三是基于社交',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '裂变的拼团模式，四是通过百亿补贴、趣味游戏、新客优惠、高频低价等促销手段，快速聚拢起已经成熟化的庞大网购用户',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '流量，以更快的速度迅速崛起；同时，一批小而美、模式独特的垂直电商也不断涌现，如：以小红书等为代表的基于消费体',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '验的“种草”传播，以淘系、京东、苏宁等为代表的基于线上线下融合的O2O，以天猫国际、京东全球购为代表的基于买手精',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '选的跨境购等，开启了我国电商发展的新阶段；而且，快手、抖音、B站等娱乐大厂通过将娱乐流量进行高效转化，原本作',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '为商业引流的渠道工具，目前也正快速成长为独立的第三代基于直播带货的综合电商平台。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 13,
#   'text': '■渠道下沉：我国三线城市及以下区域为主的“下沉市场”正接管电商流量增长的重任，这里包括近300个地级市、3000',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 13,
#   'text': '多个县城、4万个乡镇、66万个村庄，以及将近10亿的消费人口，网购潜力如同“大水里的大鱼”，逐渐成为互联网下半场流',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '量开发的新价值洼地。自2018年以来，在高性价比便捷快递服务网络的有力支撑下，社交拼团模式迅速崛起，拼多多、淘宝、',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '京东等大型综合电商平台快速推进渠道下沉引流工作。通过重组渠道下沉品牌、创新C2M供销模式、塑造廉价品牌工厂、',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '引入地理标志产品等模式，砍掉传统的采购、批发、运输、零售等中间商供应链环节，把老百姓日常需要的、质优价廉的实',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '惠商品从工厂、农田、山头直通家庭、餐桌和消费者。同时，通过新客奖励、复购优惠、现金补贴、X.99元包邮、累购返现、',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '会员送券等一系列多、快、好、省的营销模式，将营销学、行为学、心理学精巧结合，精心培育三线以下城市及县域、乡镇、',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '农村等数亿购物人群的网络购物习惯，引导他们把日常购物的流量由线下往线上转移。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 13,
#   'text': '■农产品上行：2017年以来，以拼多多、淘宝、京东等为代表的电商平台持续下沉、深耕农村市场，农村电子商务已经',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 13,
#   'text': '发展成为高效链接农产品供需两端、助力农产品上行的重要流通渠道，譬如云南的松茸、陕西的苹果、四川的猕猴桃、杭州',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '天目山的小甘薯、阳澄湖大闸蟹等具有浓郁地方特色的绿色特产、农副产品通过网购走向全国。同时，国家也先后出台一系',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '列专项政策予以大力支持。2020年7月，国家邮政局启动“快递进村”工程，并制定了《“快递进村”三年行动方案（2020-2022',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '年）》，明确到2022年年底，符合条件的建制村基本实现“村村通快递”。2021年1月4日，国务院《关于全面推进乡村振兴加',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '快农业农村现代化的意见》明确指出：“全面促进农村消费”，“加快完善县乡村三级农村物流体系，深入推进电子商务进农',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '村和农产品出村进城，推动城乡生产与消费有效对接”，“加快实施农产品仓储保鲜冷链物流设施建设工程，推进田头小型仓',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '储保鲜冷链设施、产地低温直销配送中心、国家骨干冷链物流基地建设”。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 13,
#   'text': '2020年4月21日，拼多多发布《2019年农产品上行发展报告》显示，2019年平台农（副）产品活跃商家数量达58.6万，',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 13,
#   'text': '较上年同比增长142%，直连农业生产者超过1200万；平台农（副）产品成交额达1364亿元，较上年同期增长109%；平台农',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '（副）产品年活跃买家数达2.4亿，较上年同比增长174%，复购率超过70%。另外，根据CNNIC及商务部相关统计数据：截',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '至2020年末，农村网民数量突破3.09亿，电子商务进农村实现对832个贫困县全覆盖，全国农村网络零售额由2014年的1800',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 13,
#   'text': '亿元，增长到2020年的1.79万亿元，6年交易额增长了近10倍。我们预计，随着下沉区域网络用户持续增长及农产品上行持',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 14,
#   'text': '续推进，工业品和农产品通过电商在城乡之间将高效流通，持续向快递产业释放包裹红利。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 14,
#   'text': '■直播带货：随着快手、抖音、哔哩哔哩等视频大平台娱乐流量的有效转化，粉丝经济、网红经济、直播经济爆炸式发',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 14,
#   'text': '展，公/私域流量下的直播带货已经成为高度产业化的“现象级”营销模式，并开启了电商与直播、短视频内容提供商的深度',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 14,
#   'text': '融合，实现商品在全渠道、全客群的分层式、精准式营销。而且，直播的现实感和直播场景的灵活化，赋予了网红带货产品',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 14,
#   'text': '的广泛性，包括但不限于汽车、餐饮、家具、家电、美妆、服装、数码、日用品等领域，只要可以放进购物车，万物皆可播。',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 14,
#   'text': '目前，“直播带货”已经展现了强大的流量威力。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 14,
#   'text': '报告期，网络直播已经成为“线上引流+实体消费”的数字经济新模式，带动电商直播产业蓬勃发展。根据CNNIC及商务',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 14,
#   'text': '部相关统计数据：截至2020年12月，我国网络直播用户规模达6.17亿，较2020年3月增长5703万，占网民整体的62.4%，其中：',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 14,
#   'text': '电商直播用户规模已达3.88亿，占网民整体的39.2%，近66.2%的直播用户直接转化为网购消费者。另据艾媒咨询发布的',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 14,
#   'text': '《2020-2021中国在线直播行业年度研究报告》显示，2020年全国电商直播超过2000万场；2017-2020直播电商行业市场规模',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 14,
#   'text': '分别为196亿元、1354亿元、4338亿元和9610亿元，市场规模三年增长率高达49倍。因此，随着5G技术覆盖率提升以及疫情',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 14,
#   'text': '对居民消费场景、消费习惯的改变，基于“宅文化”下直播网购所呈现的娱乐性、互动性、体验性优势，预计电商直播将具备',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 14,
#   'text': '较大发展空间，可以说网红带货已经成为打开新经济大门的新钥匙，已经成为刺激网络消费增长的新动能。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 14, 'text': '', 'type': 'image', 'text_flag': -1},
#  {'page_number': 14,
#   'text': '■生活场景快递化：“柴米油盐酱醋茶，快递包裹送到家”。随着线上消费高频和网购习惯的养成，以及驿站、快递超市、',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 14,
#   'text': '智能快递柜等末端服务基础设施的普及，同时公众号、小程序、APP等寄递渠道多元便捷、触手可及，人们生活场景快递化',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 14,
#   'text': '的趋势越来越明显。快递的应用场景正充满生活的每一个角落：从同城鲜花、蛋糕、菜场、商超的配送，到代买药、代取送',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 14,
#   'text': '物等跑腿业务；从高校开学季、毕业季、寒暑假等物品的寄递，到亲戚朋友之间个人物品的递送、赠送；从服装、化妆品、',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 14,
#   'text': '小电器等耐用品的退换货，到工厂、维修店的零部件配送，收寄包裹已经成为老百姓生活中的日常事。生活场景快递化，将',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 14,
#   'text': '持续改变人们之间物品的流通方式，也将释放越来越多的快递包裹。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 14,
#   'text': '2020年我国快递包裹总量为833.6亿件，预计2021年快递包裹总量将达千亿级。展望未来，在“互联网+消费”深度融合、',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 14,
#   'text': '电商渠道加速下沉、城乡发展齐头并进作用下，我国电子商务经济的刚需消费效应、消费分级效应和持续渗透效应愈加明',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 14,
#   'text': '显，新的网购需求正加快培育；同时，高品质快递服务正同步跟进，快递的应用场景将广泛延伸至通商业、通消费、通贸',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 15,
#   'text': '易、通生产、通生活、通办公等，快递服务正为网购经济插上腾飞的翅膀，全天候、全覆盖的快递包裹“泛在化”时代已经',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 15, 'text': '到来。 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 15,
#   'text': '3、快递产业发展的格局正迎来嬗变 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 15,
#   'text': '（1）市场竞争阶段性加剧 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 15,
#   'text': '■局部市场竞争升温：2020年第一季度，突如其来的新冠疫情给世界及我国经济社会发展带来了严重冲击，我国快递产',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 15,
#   'text': '业发展也受到疫情的严重影响，快递企业普遍出现了量能不足的困难局面。第二季度以来，随着国内疫情得到有效控制，中',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 15,
#   'text': '央及各级政府相继出台了“减税、降费、促消费”等一揽子稳定经济的措施，我国经济表现出了强劲的韧性，呈现出生产回升、',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 15,
#   'text': '消费回补的良好态势，有力地促进线上消费异常活跃，快递企业抓住有利时机，纷纷在短时期内集中回补业务量，客观上形',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 15,
#   'text': '成了第二季度局部地区的市场竞争比较激烈的局面。同时，鉴于快递产业广阔的发展空间和巨大的市场机会，少部分快递企',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 15,
#   'text': '业以补贴市场的方式，以较为激进的价格政策进行低价竞争、快速获量，导致广州、义乌等地区的快递单价下行明显。 ',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 15,
#   'text': '■行业环境环比乐观：在市场经济和法治环境下，有效的资源最终会被优化配置，企业最终要回归“量本利”的经营逻辑',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 15,
#   'text': '轨道，科技创新、服务品质与产品分层能力才是获得客户粘性、提升市场份额、体现企业核心竞争力的决定性因素。快递物',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 15,
#   'text': '流行业的业务本质，是企业向客户提供的针对物品物理位移变化的服务履约能力，概而言之是又快、又好、又安全地配送',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 15,
#   'text': '包裹，而履约过程中涉及一系列的资产工具承载、组织网络实施和服务标准保障。但是，如果企业没有经过长期的核心资',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 15,
#   'text': '产投入，没有长期的科技能力积累，没有长期共生式的网络和品牌建设，没有基于时效和服务的产品分层能力，其履约能力',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 15,
#   'text': '是无法通过凭空来完成的；短期的以价换量、低价竞争不过是企业与市场相互“薅羊毛”行为，更遑论甚至以远低于成本价格',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 15,
#   'text': '进行拼抢客户，已经涉嫌严重扰乱市场的违法“倾销”行为，不可持续。实践证明，当业务量日益增大、补贴力度衰减乃至取',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 15,
#   'text': '消、时效与服务品质可比没有优势的情景下，低价竞争者获得增量包裹的能力会明显下降，已经获取的客户也可能快速流失。 ',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 15, 'text': '', 'type': 'image', 'text_flag': -1},
#  {'page_number': 15,
#   'text': '特别是，自2020年8月份以来，疫情影响、集中补量、烧钱补贴等导致快递价格非正常性下行的诸多因素正逐步弱化或',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 15,
#   'text': '消失，有效竞争者持续减少，市场格局进一步明朗，单票收入环比持续改善，成本壁垒下的护城河效应增强。根据对月度、',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '季度市场数据的监测，我们认为，2020年第二、三季度快递行业竞争加剧属于短期现象、阶段性行为，快递行业的运行环',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '境季度环比正在修复向好，并乐观预计2021年市场环境会不断改善。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 16,
#   'text': '（2）行业发展格局正在演变 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 16,
#   'text': '■行业“马太效应”加剧：报告期，在新进入者低价竞争以及头部快递企业规模化、集约化发展优势冲击下，伴随着主动',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 16,
#   'text': '或被动式的差异化发展及越来越高的行业壁垒，部分快递企业的生产经营活动正面临困难，特别是在核心资产投入、科技创',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '新、融资能力、管理管控、网络均衡性等方面遭遇困境，导致获取包裹的能力不足，盈利能力越来越差，经营现金流日趋紧',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '张，网络的稳定性明显下降，生存空间持续萎缩。特别是“11.11”、“12.12”、“年货节”等业务旺季，既严峻考验快递企业的',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '峰值产能、服务水平、时效管理等核心能力，又密切关系电商平台和B端商家的声誉、口碑与成本，基于理性与信赖预期，',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '导致货品加速向龙头快递企业集中，呈现“包裹虹吸”现象。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 16,
#   'text': '从品牌数量、产能建设、获量能力及市场份额角度看，目前低质效的二三线快递产能已基本出清，头部企业之间的发',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 16,
#   'text': '展格局也已经呈现出“份额下滑-份额维持-份额进取”的持续分化梯度，“马太效应”越来越明显。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 16,
#   'text': '■差异化发展正在形成：发展战略上，基于对行业发展前景的不同认识和前瞻判断，各企业分别制定了不同的发展战略，',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 16,
#   'text': '并有针对性地进行核心资产资源投入、业务布局和产品开发，相继呈现出不同的发展状态和竞争能力；货品结构上，快递产',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '品进一步细分，由传统的“标准快递”逐渐向附加值更高的时效产品、特色产品、定制化产品细分，由过去大小包裹混合的“粗',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '放型产品”逐渐向小件包裹、大包裹细分；服务能力上，由于信息化、精细化管理能力差异，快递企业在全程时效管理水平',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '和服务能力上逐渐显现梯度，头部企业的快递服务水平持续提升，全程时效持续提高，品牌效应持续补强；获客方式上，相',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '较低质效品牌过度依赖“以价换量”而言，龙头快递企业基于科技强、服务好、时效快等品牌优势，更有能力实施“提质增量”、',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '“产品分层”等差异化竞争策略。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 16,
#   'text': '目前，标准快递方面，头部快递企业日均单量已超过4000万票，剔除派费后的单票运输中转成本已降至0.9元以下，且',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 16,
#   'text': '未来将持续呈现明显的规模效应和集约效应；产品分层方面，头部快递企业正持续开拓特快、农产品件、隐私面单、派前',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '电联等高附加值产品与服务，同城、冷链业务也将进入最佳布局窗口期。可以预计，以标准快递为基础，有能力实施客户',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '分群、产品分层等差异化、高品质服务的综合物流快递企业，将获得更大的品牌优势、产品优势和发展空间。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 16,
#   'text': '（3）高品质服务构筑行业壁垒 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 16,
#   'text': '■高品质服务是常态：在资本支持、科技创新、信息化管理等诸要素作用下，我国快递产业的发展正在经历由小到强、',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 16,
#   'text': '由人工分拣向自动化操作、由粗放管理向数字化阶段转变。特别是头部企业，快递服务网络已经具备了稳定、高效、智慧化',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '特性，与区域性快递网络相比较，在品牌效应、服务品质、全程时效等方面已经具备了可识别、可信赖、可预期的明显差异',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '化特征。根据国家邮政局数据统计，有效申诉率方面：我国头部快递服务企业的有效申诉率连续多年持续下降，2019年以来',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '无限趋近于0（每百万件）；全程时效方面：发达区域，1200公里内快递全程时效持续缩短，龙头企业已跨进48小时，0-800',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '公里及京津冀、长三角、珠三角、江浙沪等主要经济带范围内，“今发明至”已接近常态时效。可以说，高品质、快时效的快',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 16,
#   'text': '递服务已经成为大平台、大电商、高客单价B端遴选快递服务合作伙伴的首要维度，也是C端消费者对快递需求和服务评价',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 17, 'text': '的常态化预期。 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 17,
#   'text': '■海量包裹下的压力测试：在快递服务品质持续提高的同时，快递包裹量也呈几何级增长。2013年—2020年，我国快递',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 17,
#   'text': '包裹量由91.9亿件增长为833.6亿件，年复合增长率达37%，目前近年正以近200亿件的增量突飞猛进，海量包裹的压力测试',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 17,
#   'text': '时刻存在。一方面，快递企业需要在资本开支、科技创新、自动化投入、运能提升、路由规划等方面具备持续的资源投入能',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 17,
#   'text': '力和精细管理能力；另一方面，还需要在末端建设、服务管控、利益平衡等方面持续具备“绣花式管理”和网络协同能力，服',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 17,
#   'text': '务网络既需要保持稳定性、平衡性，又需要有合理的张弛性和迸发力；同时，在大规模包裹存量及每年百亿级增量环境下，',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 17,
#   'text': '市场端充分的价格竞争和企业端成本的微妙波动，对快递企业和网络加盟商的现金流、营业利润、融资能力而言都富有挑战。',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 17,
#   'text': '头部快递企业在科技实力、精细管理、服务能力等方面已经市场、客户和消费者的充分检验，而对于区域快递企业或新闯入',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 17,
#   'text': '者而言，在市场处于充分竞争的环境下，短期内或仅依靠资本的力量拟建立一张稳定、高效并且具备盈利能力的服务网络，',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 17, 'text': '是不小的挑战。 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 17,
#   'text': '我们认为，在千亿级海量包裹的大背景下，消费者对快递时效的要求越来越快，对服务品质的要求越来越高，头部快',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 17,
#   'text': '递企业凭借领先的科技能力、精益的管理水平和稳定的服务网络，在“服务品质-业务量-成本-利润”之间已经牢牢构筑起高',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 17,
#   'text': '深的快递行业壁垒；新进入者通过烧钱、补贴行为快速获量是短期行为，不是核心竞争力的体现，不可持续。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 17,
#   'text': '4、快递产业具有区域不平衡和季节性特点 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 17,
#   'text': '受经济发展水平不均衡影响，我国电商产业发展具有明显的区域差异，并由此导致区域之间快递包裹量特别是发件/揽',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 17,
#   'text': '件地业务量差别较大，其中浙江义乌、上海、北京、广州等地具有明显的代表性；同时，受购物季、打折季等电商造节促销',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 17,
#   'text': '因素影响，以及中秋、春节等传统重大节假日带来的消费需求，我国线上消费及包裹量又呈现明显的季节性特征。区域不平',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 17,
#   'text': '衡和季节性特点，客观上对我国快递企业的产能布局、路线优化、成本管控及服务品质等方面构成一定程度的影响。 ',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 17, 'text': '（1）区域性 ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 17,
#   'text': '我国快递行业区域性明显，快递需求和快递企业集中于东部，市场地域区分占比较为稳定。长三角、珠三角和京津冀地',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 17,
#   'text': '区是我国产业集中、经济发展迅速的地区，产业经营水平和居民消费水平都相对较高，快递流出流入持续保持较大的需求；',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 17,
#   'text': '中西部地区经济发展水平相对较低，对于快递流入的需求大于流出需求，造成中西部地区快递业务量和业务收入占比远小于',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 17,
#   'text': '东部地区，但中西部地区快递业务潜力巨大。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 18, 'text': '', 'type': 'image', 'text_flag': -1},
#  {'page_number': 18,
#   'text': '根据国家邮政局统计，2020年，我国东、中、西部地区快递业务量比重分别为79.4%、13.3%和7.3%，业务收入比重分',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 18,
#   'text': '别为79.6%、11.9%和8.5%。与去年同期相比，东部地区快递业务量比重下降0.3个百分点，快递业务收入比重下降0.6个百分',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 18,
#   'text': '点；中部地区快递业务量比重上升0.4个百分点，快递业务收入比重上升0.6个百分点；西部地区快递业务量比重下降0.1个百',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 18,
#   'text': '分点，快递业务收入比重基本持平。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 18, 'text': '（2）季节性 ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 18,
#   'text': '我国快递行业受益电商“6.18购物节”、“双十一”、“双十二”、“年货节”等促销活动和公众年末采购需求的影响，具有季',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 18,
#   'text': '节性特征，景气度基本呈逐月高企趋势，其中：第一季度由于春节假期等原因为行业淡季，第四季度受购物节促销等带动是',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 18,
#   'text': '快递行业的旺季，但快递行业的季节性相对稳定，未因业务规模的增加发生明显变化。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 18,
#   'text': '根据国家邮政局的相关统计数据，2020年第一季度的快递业务量为125.3亿件，约占全年包裹量的15.03%，第四季度的',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 18,
#   'text': '快递业务量为272.1亿票，约占全年包裹量的32.64%。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 18, 'text': '', 'type': 'image', 'text_flag': -1},
#  {'page_number': 18,
#   'text': '5、韵达股份是我国快递产业领军企业之一 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 19,
#   'text': '韵达股份作为国内快递行业第一梯队的领军企业之一，近年来公司持续夯实基础设施底盘建设，在枢纽转运中心、设备',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 19,
#   'text': '自动化智能化、运力运能提升、数字化信息化建设等核心资产方面持续投入，并将网络信息平台、自动化智能化设备与业务',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 19,
#   'text': '深度融合，实现了业务量、市场份额的高速增长，并保障快件时效、人均效能、运营效率和服务质量等管理指标的持续提升。 ',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 19,
#   'text': '■快递业务稳健增长：韵达2020年业务量依旧保持高速增长，达141.44亿件，同比增速达41.02%；市场份额达16.97%，',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 19, 'text': '', 'type': 'image', 'text_flag': -1},
#  {'page_number': 19, 'text': '排名行业第二。 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 19,
#   'text': '■服务品质持续领先：快递服务时限方面，根据国家邮政局发布的《关于2020年快递服务满意度调查和时限测试结果的',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 19,
#   'text': '通告》，全国重点地区主要快递企业的服务时限准时率进行测试排名中，前五名依次为顺丰速运、邮政EMS、京东快递、',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 19,
#   'text': '中通快递、韵达速递，其中：72小时准时率在可比同行中的全程时限排名第2，寄出地处理时限仅次于顺丰，寄达地处理时',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 19,
#   'text': '效仅次于顺丰和邮政。快递服务满意度方面，主要快递企业总体满意度前五名依次为顺丰速运、京东快递、邮政EMS、中',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 19,
#   'text': '通快递、韵达速递。韵达快递服务时效和服务水平在可比公司中持续保持领先优势。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 19,
#   'text': '■品牌美誉度继续提升：报告期，根据胡润研究院发布的《2020胡润品牌榜》和《2020胡润最具价值民营品牌》，2020',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 19,
#   'text': '年韵达分别排名第156名和第94名；公司荣获中华全国工商业联合会颁发的“2020中国服务业民营企业100强”和“2020中国民',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 19,
#   'text': '营企业500强”，荣获由《快递》杂志、《中国邮政快递报》等颁发的“2020精细化管理奖”、 “2020快递抗疫贡献特别奖”、“2020',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 19,
#   'text': '快递社会责任奖”，公司董事长兼总裁聂腾云先生获得“2020快递行业影响力人物”大奖。  ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 19, 'text': '二、主要资产重大变化情况 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 19, 'text': '1、主要资产重大变化情况 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 19,
#   'text': [['', ''], ['主要资产', '重大变化说明'], ['', ''], ['股权资产', '本期无重大变化']],
#   'type': 'table',
#   'text_flag': 1},
#  {'page_number': 20,
#   'text': [['固定资产', '主要系报告期内房屋及建筑物、车辆、机器设备资产增加所致'],
#    ['无形资产', '主要系报告期内购买计算机软件、土地所致'],
#    ['', '主要系黑龙江、山东、湖北、江苏等快递电商总部基地项目、韵达集团北方区域总'],
#    ['在建工程', None],
#    [None, '部物流建设项目等增加所致'],
#    ['', None],
#    ['货币资金', '主要系报告期内短期借款、应付债券增加，收回交易性金融资产所致'],
#    ['其他应收款', '主要系报告期内备用金、押金及保证金增加所致'],
#    ['存货', '主要系报告期内购买环保袋等周转材料增加所致'],
#    ['其他流动资产', '主要系报告期内预缴增值税、企业所得税等增加所致'],
#    ['', '主要系报告期内可抵扣亏损、资产减值准备、递延收益、外汇货币工具公允价值变'],
#    ['递延所得税资产', None],
#    [None, '动增加所致'],
#    ['', None],
#    ['其他非流动资产', '主要系报告期内预付土地出让金、设备款、工程款增加所致']],
#   'type': 'table',
#   'text_flag': 2},
#  {'page_number': 20, 'text': '2、主要境外资产情况 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 20,
#   'text': [['', '', '', '', '', '', '境外资产占', ''],
#    [None, None, None, None, None, None, None, '是否存在重'],
#    ['资产的具体内容', '形成原因', '资产规模（元）', '所在地', '运营模式', '收益状况（元）', '公司净资产', None],
#    [None, None, None, None, None, None, None, '大减值风险'],
#    ['', '', '', '', '', '', '的比重', None],
#    [None, None, None, None, None, None, None, ''],
#    ['韵达速递物流（香', '', '', '', '', '', '', ''],
#    [None, '出资设立', '266,852,739.71', '中国香港', '投资管理', '92,982.09', '1.85%', '否'],
#    ['港）有限公司', None, None, None, None, None, None, None],
#    [None, '', '', '', '', '', '', ''],
#    ['韵达物流科技（香', '', '', '', '国际货物运', '', '', ''],
#    [None,
#     '出资设立',
#     '16,126,651.30',
#     '中国香港',
#     None,
#     '-6,943,271.81',
#     '0.11%',
#     '否'],
#    ['港）有限公司', None, None, None, '输及代理', None, None, None],
#    [None, '', '', '', None, '', '', ''],
#    ['YUNDA Holding', '', '', '英属维尔京', '', '', '', ''],
#    [None,
#     '出资设立',
#     '3,265,070,242.77',
#     None,
#     '投资管理',
#     '-15,914,799.51',
#     '22.58%',
#     '否'],
#    ['Investment Limited', None, None, '群岛', None, None, None, None],
#    [None, '', '', None, '', '', '', '']],
#   'type': 'table',
#   'text_flag': 1},
#  {'page_number': 20, 'text': '三、核心竞争力分析 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 20,
#   'text': '近年来，特别是上市以来，公司站在国内外宏观经济发展演变的高点，结合对移动互联网技术、电商经济和快递产业发',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 20,
#   'text': '展趋势的认识，以全局的观点制定了科学的发展战略，并据此在科技能力、资源能力、经营能力、人才能力等方面持续构筑',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 20, 'text': '较深的护城河和比较优势。 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 20,
#   'text': '（一）公司拥有在全网全链路实施一体式数智化管理管控的领先优势 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 20,
#   'text': '2020年以来，公司秉着对科技孜孜不倦的探索，以科技创新、智慧管理为驱动，聚焦全网核心资源、核心模块，在转运',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 20, 'text': '', 'type': 'image', 'text_flag': -1},
#  {'page_number': 21,
#   'text': '中心、干线运输、大数据决策、智慧服务、网络末端、客户开发等核心功能区深入进行信息化、数据化、智慧化建设和升级，',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 21,
#   'text': '在全网全链路实现一体式、数智化管理管控方面已经形成了明显的竞争优势，促使科技技术与精细化运营管理完美结合，助',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 21,
#   'text': '力公司向物流科技集团转型，打造以快递业务为核心、周边产业链协同布局发展的科技型服务公司。报告期，公司持续保持',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 21,
#   'text': '信息化、数智化建设和科技创新投入力度，在信息系统开发、软硬件采购、服务外包合作等方面的资本开支为7.22亿元，同',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 21, 'text': '比增长46.02%。 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 21,
#   'text': '1、夯实信息基础设施建设，强化数字科技中台优势 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 21, 'text': '1.1 大数据生态建设 ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 21,
#   'text': '2020年，公司继续加大在大数据方面的科研投入，大数据技术实力获得稳步提升。公司基于实时流处理和数据中台技术，',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 21,
#   'text': '构建了流批一体的混合生态大数据平台能力，持续优化实时大数据采集、处理、分析和运维能力，可实时处理10亿级数据，',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 21,
#   'text': '持续赋能业务各个生态链，建立了协同、兼容的多层次数据建设平台，实现了“将韵达装入计算机中”。  ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 21,
#   'text': ' ■计算实时化：建设实时大数据平台，实时采集、处理和分析数据，峰值到达10亿级别；打造业务实时指标体系，指标',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 21,
#   'text': '计算秒级响应，实现票件全生命周期各个业务环节全链路监控，用数据驱动业务，逐步提升时效、服务质量和客户满意度。 ',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 21,
#   'text': ' ■响应快速化：基于业务快速构建数据分析体系，基于BI工具的能力快速建模、交互式的设计和丰富的可视化组件，构',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 21,
#   'text': '建600+的面向多个业务部门的数据报表体系，由数据服务大厅统一提供服务；进一步提升快递、仓储、大末端、国际、供',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 21,
#   'text': '应链等多个板块的业务拓展服务质量。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 21,
#   'text': ' ■大数据平台构建引擎：提供从数据接入到数据消费全链路的智能数据构建与管理的大数据能力，包括产品、技术和方',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 21,
#   'text': '法论等，助力打造标准统一、融会贯通、资产化、服务化、闭环自优化的智能数据体系，以驱动创新；通过实时数据采集、',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 21,
#   'text': '离线数据采集，构建OneData，OneID和OneService体系，沉淀大末端标签，为识别算法构建落地奠定基础，为多渠道的智能',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 21,
#   'text': '推荐提供强有力的平台和数据输入。实现网站、APP、PC客户端、小程序等全业务属性的日志规范采集；夯实基础数据建',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 21,
#   'text': '设，构建主题域、业务过程、分析维度模型，输出上万个分析指标，实现全业务数据的大盘浏览和资产检索。  ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 21, 'text': '1.2 移动研发平台 ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 21,
#   'text': '在业务加速数字化、移动化的趋势下，公司构建的一站式研发平台，以更敏捷、快速的方式来适应瞬息万变的市场环境',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 21,
#   'text': '和愈加复杂的系统需求。“韵达中台”是基于行业领先的实践基础上所沉淀出来的研发平台，能有效提高业务开发效率，减少',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 21,
#   'text': '研发成本，快速响应市场，是业务体系化、生态化、数字化的关键支撑。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 22,
#   'text': '研发平台的建设解决研发流程中从开发到运营等端到端的所有问题，彻底解决开发的技术难点，为集团业务提速。目前，',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 22,
#   'text': '研发平台已经覆盖了公司各业务线，接受洪峰考验。实现研发效率的倍速提升、秒级发现故障，分钟级定位故障。 ',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 22, 'text': '', 'type': 'image', 'text_flag': -1},
#  {'page_number': 22,
#   'text': '1.3 筑牢信息安全基石 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 22,
# ...
#    ['永安韵吉电子商务有限公司', '新设', '未产生重大影响'],
#    ['福州凌怡电子商务有限公司', '新设', '未产生重大影响'],
#    ['福州沁明电子商务有限公司', '新设', '未产生重大影响'],
#    ['永安韵松电子商务有限公司', '新设', '未产生重大影响'],
#    ['永安韵泉电子商务有限公司', '新设', '未产生重大影响'],
#    ['福州艾欣电子商务有限公司', '新设', '未产生重大影响'],
#    ['永安韵安电子商务有限公司', '新设', '未产生重大影响'],
#    ['昆明韵达电子商务有限公司', '新设', '未产生重大影响'],
#    ['福州玖弘电子商务有限公司', '新设', '未产生重大影响'],
#    ['廊坊简硕货运代理有限公司', '新设', '未产生重大影响'],
#    ['沧州硕浩电子商务有限公司', '新设', '未产生重大影响'],
#    ['福州有润电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州玄讯电子科技有限公司', '新设', '未产生重大影响'],
#    ['杭州普钰信息技术有限公司', '新设', '未产生重大影响'],
#    ['杭州芳铭科技有限公司', '新设', '未产生重大影响'],
#    ['杭州冰凌科技有限公司', '新设', '未产生重大影响'],
#    ['杭州杭枫商务服务有限公司', '新设', '未产生重大影响'],
#    ['上海巽捷实业有限公司', '新设', '未产生重大影响'],
#    ['上海皓松实业有限公司', '新设', '未产生重大影响'],
#    ['杭州亿凤科技有限公司', '新设', '未产生重大影响']],
#   'type': 'table',
#   'text_flag': 2},
#  {'page_number': 63,
#   'text': [['上海仁柏实业有限公司', '新设', '未产生重大影响'],
#    ['上海谷顺实业有限公司', '新设', '未产生重大影响'],
#    ['上海韵诺实业有限公司', '新设', '未产生重大影响'],
#    ['杭州剑兰科技有限公司', '新设', '未产生重大影响'],
#    ['杭州名坞科技有限公司', '新设', '未产生重大影响'],
#    ['上海笙楷实业有限公司', '新设', '未产生重大影响'],
#    ['杭州丹盛实业有限公司', '新设', '未产生重大影响'],
#    ['杭州庆鸿电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州语玉科技有限公司', '新设', '未产生重大影响'],
#    ['杭州酷伴电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州海椰网络科技有限公司', '新设', '未产生重大影响'],
#    ['杭州华勤物流科技有限公司', '新设', '未产生重大影响'],
#    ['内蒙古达必韵电子商务有限公司', '新设', '未产生重大影响'],
#    ['广州云宸供应链管理有限公司', '新设', '未产生重大影响'],
#    ['上海彦松实业有限公司', '新设', '未产生重大影响'],
#    ['兰溪兰韵电子商务有限公司', '新设', '未产生重大影响'],
#    ['上海韵卫实业有限公司', '新设', '未产生重大影响'],
#    ['杭州韵鑫实业有限公司', '新设', '未产生重大影响'],
#    ['上海彦琪实业有限公司', '新设', '未产生重大影响'],
#    ['邯郸韵安电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州味觉科技有限公司', '新设', '未产生重大影响'],
#    ['杭州慕锡实业有限公司', '新设', '未产生重大影响'],
#    ['济南云鹏供应链管理有限公司', '新设', '未产生重大影响'],
#    ['杭州若珩商务服务有限公司', '新设', '未产生重大影响'],
#    ['上海韵至达实业有限公司', '新设', '未产生重大影响'],
#    ['马鞍山韵凯电子商务有限公司', '新设', '未产生重大影响'],
#    ['巢湖市衢棋商贸有限公司', '新设', '未产生重大影响'],
#    ['杭州韵安实业有限公司', '新设', '未产生重大影响'],
#    ['上海韵达申荟进出口有限公司', '新设', '未产生重大影响'],
#    ['上海源沁实业有限公司', '新设', '未产生重大影响'],
#    ['上海微沣实业有限公司', '新设', '未产生重大影响'],
#    ['杭州花裕商务服务有限公司', '新设', '未产生重大影响'],
#    ['杭州凌冽科技有限公司', '新设', '未产生重大影响'],
#    ['杭州欣茂商务服务有限公司', '新设', '未产生重大影响']],
#   'type': 'table',
#   'text_flag': 2},
#  {'page_number': 64,
#   'text': [['汕头市云翔供应链管理有限公司', '新设', '未产生重大影响'],
#    ['沧州好彤电子商务有限公司', '新设', '未产生重大影响'],
#    ['沧州霖沣电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州泓申电子商务有限公司', '新设', '未产生重大影响'],
#    ['上海友琪实业有限公司', '新设', '未产生重大影响'],
#    ['上海诺冰实业有限公司', '新设', '未产生重大影响'],
#    ['上海韵鑫实业有限公司', '新设', '未产生重大影响'],
#    ['上海琪思实业有限公司', '新设', '未产生重大影响'],
#    ['上海霖衍实业有限公司', '新设', '未产生重大影响'],
#    ['上海亦泉实业有限公司', '新设', '未产生重大影响'],
#    ['凤阳聚韵电子商务有限公司', '新设', '未产生重大影响'],
#    ['凤阳优韵电子商务有限公司', '新设', '未产生重大影响'],
#    ['上海韵达轻旅供应链管理有限公司', '新设', '未产生重大影响'],
#    ['浙江韵测科技有限公司', '新设', '未产生重大影响'],
#    ['江西祺律科技有限公司', '新设', '未产生重大影响'],
#    ['南昌宸励电子商务有限公司', '新设', '未产生重大影响'],
#    ['江西宸律电子商务有限公司', '新设', '未产生重大影响'],
#    ['驻马店优泰物流有限公司', '新设', '未产生重大影响'],
#    ['上海冰阡实业有限公司', '新设', '未产生重大影响'],
#    ['YUNDA Holding Investment Limited', '新设', '未产生重大影响'],
#    ['上海霖泰物流有限公司', '新设', '未产生重大影响'],
#    ['芜湖沐和物流有限公司', '新设', '未产生重大影响'],
#    ['上海纳韵货运代理有限公司', '新设', '未产生重大影响'],
#    ['芜湖松沁物流有限公司', '新设', '未产生重大影响'],
#    ['上海衍沁物流有限公司', '新设', '未产生重大影响'],
#    ['贵州韵达电子商务有限公司', '新设', '未产生重大影响'],
#    ['上海韵鲜物流科技有限公司', '新设', '未产生重大影响'],
#    ['上海韵达网络科技有限公司', '新设', '未产生重大影响'],
#    ['徐州韵必达电子商务有限公司', '新设', '未产生重大影响'],
#    ['南昌皓思物流有限公司', '新设', '未产生重大影响'],
#    ['南昌律源物流有限公司', '新设', '未产生重大影响'],
#    ['南昌浩明物流有限公司', '新设', '未产生重大影响'],
#    ['徐州韵至达电子商务有限公司', '新设', '未产生重大影响'],
#    ['漯河仁迈实业有限公司', '新设', '未产生重大影响']],
#   'type': 'table',
#   'text_flag': 2},
#  {'page_number': 65,
#   'text': [['漯河润雅实业有限公司', '新设', '未产生重大影响'],
#    ['Heyun Investment Limited', '新设', '未产生重大影响'],
#    ['邯郸韵诺电子商务有限公司', '新设', '未产生重大影响'],
#    ['邯郸韵吉电子商务有限公司', '新设', '未产生重大影响'],
#    ['盘锦韵必达速递有限公司', '新设', '未产生重大影响'],
#    ['泰州韵彦电子商务有限公司', '新设', '未产生重大影响'],
#    ['义乌市蜜罐信息技术有限公司', '新设', '未产生重大影响'],
#    ['杭州满致网络科技有限公司', '新设', '未产生重大影响'],
#    ['芜湖纯上电子商务有限公司', '新设', '未产生重大影响'],
#    ['巢湖市曲从电子商务有限公司', '新设', '未产生重大影响'],
#    ['巢湖市曲聚电子商务有限公司', '新设', '未产生重大影响'],
#    ['巢湖市曲领电子商务有限公司', '新设', '未产生重大影响'],
#    ['马鞍山韵吉电子商务有限公司', '新设', '未产生重大影响'],
#    ['马鞍山韵欣电子商务有限公司', '新设', '未产生重大影响'],
#    ['池州荣韵电子商务有限公司', '新设', '未产生重大影响'],
#    ['芜湖韵旭智能科技有限公司', '新设', '未产生重大影响'],
#    ['亳州韵曲电子商务有限公司', '新设', '未产生重大影响'],
#    ['江苏蜜罐供应链管理有限公司', '新设', '未产生重大影响'],
#    ['江苏蜜栈科技有限公司', '新设', '未产生重大影响'],
#    ['上海煊维嘉网络科技有限公司', '新设', '未产生重大影响'],
#    ['上海衍昕实业有限公司', '新设', '未产生重大影响'],
#    ['上海嘉雨实业有限公司', '新设', '未产生重大影响'],
#    ['上海乐沐实业有限公司', '新设', '未产生重大影响'],
#    ['上海祺立实业有限公司', '新设', '未产生重大影响'],
#    ['上海凌彤实业有限公司', '新设', '未产生重大影响'],
#    ['上海简凌实业有限公司', '新设', '未产生重大影响'],
#    ['上海松晨实业有限公司', '新设', '未产生重大影响'],
#    ['驻马店羽夙物流有限公司', '新设', '未产生重大影响'],
#    ['湖北蜜罐电子商务有限公司', '新设', '未产生重大影响'],
#    ['湖北蜜罐供应链管理有限公司', '新设', '未产生重大影响'],
#    ['湖北纯鸿电子商务服务有限公司', '新设', '未产生重大影响'],
#    ['湖北臻夙电子商务服务有限公司', '新设', '未产生重大影响'],
#    ['湖北宣沁电子商务服务有限公司', '新设', '未产生重大影响'],
#    ['湖北臻卓电子商务服务有限公司', '新设', '未产生重大影响']],
#   'type': 'table',
#   'text_flag': 2},
#  {'page_number': 66,
#   'text': [['常德乐沐电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州盈旋信息科技有限公司', '新设', '未产生重大影响'],
#    ['杭州佳羽实业有限公司', '新设', '未产生重大影响'],
#    ['杭州菲霖网络科技有限公司', '新设', '未产生重大影响'],
#    ['杭州智和电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州彦楷电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州桐达电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州沣嘉实业有限公司', '新设', '未产生重大影响'],
#    ['杭州鸿图电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州金滩电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州韵楷实业有限公司', '新设', '未产生重大影响'],
#    ['温州韵泰电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州殷勤电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州裕勋电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州昕泰实业有限公司', '新设', '未产生重大影响'],
#    ['杭州宏高商务服务有限公司', '新设', '未产生重大影响'],
#    ['杭州宏友电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州香湖商务服务有限公司', '新设', '未产生重大影响'],
#    ['杭州永富电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州赋兴科技有限公司', '新设', '未产生重大影响'],
#    ['杭州汇蕴电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州凯天商务服务有限公司', '新设', '未产生重大影响'],
#    ['杭州念庐科技有限公司', '新设', '未产生重大影响'],
#    ['杭州硕耀实业有限公司', '新设', '未产生重大影响'],
#    ['杭州岩阳科技有限公司', '新设', '未产生重大影响'],
#    ['杭州野航实业有限公司', '新设', '未产生重大影响'],
#    ['杭州裕通电子商务有限公司', '新设', '未产生重大影响'],
#    ['义乌市科昕电子商务有限公司', '新设', '未产生重大影响'],
#    ['义乌市彦昕电子商务有限公司', '新设', '未产生重大影响'],
#    ['义乌市汇韵电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州素馨科技有限公司', '新设', '未产生重大影响'],
#    ['杭州奇果科技有限公司', '新设', '未产生重大影响'],
#    ['杭州半宏实业有限公司', '新设', '未产生重大影响'],
#    ['杭州皓泉电子商务有限公司', '新设', '未产生重大影响']],
#   'type': 'table',
#   'text_flag': 2},
#  {'page_number': 67,
#   'text': [['杭州敏卓电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州桉友科技有限公司', '新设', '未产生重大影响'],
#    ['杭州坞迪科技有限公司', '新设', '未产生重大影响'],
#    ['杭州地蕴科技有限公司', '新设', '未产生重大影响'],
#    ['杭州天河电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州长溪电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州云剑科技有限公司', '新设', '未产生重大影响'],
#    ['杭州真卿电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州浣溪科技有限公司', '新设', '未产生重大影响'],
#    ['杭州波格科技有限公司', '新设', '未产生重大影响'],
#    ['杭州洽尼电子商务有限公司', '新设', '未产生重大影响'],
#    ['杭州旭韵科技有限公司', '新设', '未产生重大影响'],
#    ['杭州仙山科技有限公司', '新设', '未产生重大影响'],
#    ['杭州柯逻科技有限公司', '新设', '未产生重大影响'],
#    ['杭州凯纯实业有限公司', '新设', '未产生重大影响'],
#    ['杭州龙溪电子商务有限公司', '新设', '未产生重大影响'],
#    ['上海翔柏实业有限公司', '新设', '未产生重大影响'],
#    ['上海亦迈实业有限公司', '新设', '未产生重大影响'],
#    ['上海智彦实业有限公司', '新设', '未产生重大影响'],
#    ['上海英笙实业有限公司', '新设', '未产生重大影响'],
#    ['上海赫彦实业有限公司', '新设', '未产生重大影响'],
#    ['上海英韵实业有限公司', '新设', '未产生重大影响'],
#    ['上海萱沣实业有限公司', '新设', '未产生重大影响'],
#    ['上海耀伟实业有限公司', '新设', '未产生重大影响'],
#    ['上海鸿璟实业有限公司', '新设', '未产生重大影响'],
#    ['上海沐顺实业有限公司', '新设', '未产生重大影响'],
#    ['上海羿煊实业有限公司', '新设', '未产生重大影响'],
#    ['上海卫琴实业有限公司', '新设', '未产生重大影响'],
#    ['上海羽善实业有限公司', '新设', '未产生重大影响'],
#    ['上海利任实业有限公司', '新设', '未产生重大影响'],
#    ['亳州韵硕电子商务有限公司', '新设', '未产生重大影响'],
#    ['凤阳阔韵电子商务有限公司', '新设', '未产生重大影响'],
#    ['广西易敖电子商务有限公司', '新设', '未产生重大影响'],
#    ['广西沁煊电子商务有限公司', '新设', '未产生重大影响']],
#   'type': 'table',
#   'text_flag': 2},
#  {'page_number': 68,
#   'text': [['广西阳夙电子商务有限公司', '新设', '未产生重大影响'],
#    ['广西韵富电子商务有限公司', '新设', '未产生重大影响'],
#    ['海南韵达健康科技有限公司', '新设', '未产生重大影响'],
#    ['海南福韵实业有限公司', '新设', '未产生重大影响'],
#    ['海南韵必达投资有限公司', '新设', '未产生重大影响'],
#    ['海南福韵投资有限公司', '新设', '未产生重大影响'],
#    ['自贡韵裕电子商务有限公司', '新设', '未产生重大影响'],
#    ['韵达宏图（泉州）供应链科技有限公司', '新设', '未产生重大影响'],
#    ['四川成达云商供应链管理有限公司', '新设', '未产生重大影响'],
#    ['昆山云福供应链管理有限公司', '新设', '未产生重大影响'],
#    ['长沙云拓供应链管理有限公司', '新设', '未产生重大影响'],
#    ['卫辉市韵沣物流有限公司', '新设', '未产生重大影响'],
#    ['杭州韵鲜物流有限公司', '新设', '未产生重大影响'],
#    ['上海沁韵实业有限公司', '新设', '未产生重大影响'],
#    ['上海羽亦实业有限公司', '新设', '未产生重大影响'],
#    ['重庆勤曼网络科技有限公司', '新设', '未产生重大影响'],
#    ['天津市韵达快递服务有限公司', '清算', '未产生重大影响'],
#    ['上海弈青企业咨询服务有限责任公司', '清算', '未产生重大影响'],
#    ['芜湖韵鑫电子商务有限公司', '清算', '未产生重大影响']],
#   'type': 'table',
#   'text_flag': 2},
#  {'page_number': 68, 'text': '主要控股参股公司情况说明 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 68,
#   'text': '八、公司控制的结构化主体情况 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 68, 'text': '九、公司未来发展的展望 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 68,
#   'text': '（一）公司发展战略及经营目标  ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 68,
#   'text': '自2020年第二季度以来，我国疫情得到有效控制，我国经济增长表现出了强劲的韧性，以电商经济为代表的居民消费活',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 68,
#   'text': '动异常活跃，主要电商平台快速向下沉市场推进，直播带货及农产品上行效应显著，以地级市及以下区域为主的潜在线上购',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 68,
#   'text': '物习惯加快培育，立体式的网购经济正面临更大的发展空间，预判快递物流产业还将迎来大机遇、大发展。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 68,
#   'text': '2021年，公司将牢牢锚定“守正开放、多元协同、一超多强”的发展战略，以科技创新为根本驱动力，持续构筑转运中心、',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 68,
#   'text': '自动化设备、高效运力运能等核心资产、核心资源，持续提升全程时效和服务水平，持续推进“两进一出”工程，优化组织管',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 68,
#   'text': '理和成本控制，巩固核心竞争优势，抓住电商经济持续繁荣的关键机遇期，在包裹增量和市场份额等方面获得更进一步的发',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 69,
#   'text': '展，深入构建“以快递为核心，融合周边产业、新业务、新业态协同发展”的多层次综合物流“生态圈”。  ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 69, 'text': '（二）重点经营计划  ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 69,
#   'text': '1、打造超强的快递服务能力 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 69,
#   'text': '2021年，公司将以“全网共生，全力开拓，全面数智，全新变革”为经营发展思路，通过在网络与网点共生发展、产品分',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 69,
#   'text': '层与市场开拓、运营全面数字化可视化，以及以经营为根本的组织变革等方面聚焦用力，建立起坚实的网络实力和公司能力，',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 69,
#   'text': '保障在新格局环境下公司的业务量、市场份额、产品分层、收入与利润、科技水平及产业链延伸等方面形成新突破、开拓新',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 69, 'text': '局面，构建第二增长曲线。  ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 69, 'text': '（1）全网共建共生 ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 69,
#   'text': '■共建网络：推进集包仓、分拣仓、云仓建设，建设仓干配一体化的服务能力，在环境嬗变的背景下尤其做好网络底盘',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 69, 'text': '能力建设； ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 69,
#   'text': '■末端建设：持续加强末端门店、快递超市、菜鸟驿站联建、自提柜等建设。 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 69, 'text': '（2）全力开拓市场 ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 69,
#   'text': '■贴近客户了解市场：总部经理级对口帮扶，贴近客户，贴近市场，以客户为中心，以满足客户、网点需求为出发点，',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 69,
#   'text': '帮助客户，帮助网点创造价值； ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 69,
#   'text': '■建立分层产品能力：瞄准客户时效需求/差异化服务需求，补齐交付能力短板，推广和建设特快、同城、冷链等产品能',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 69, 'text': '力； ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 69,
#   'text': '■打造高端客户群：补齐大客户服务短板，建立行业类目解决方案、客户管理系统、客户画像等，丰富获客渠道，建立',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 69,
#   'text': '针对大客户的成本指导定价，配套完善销售体系、激励体系和服务体系，持续开发高端客户、品牌客户群，构建新的增长曲',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 69, 'text': '线。 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 69, 'text': '（3）全面数智化 ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 69,
#   'text': '■快递业务：保障业务经营全面数字化、可视化，在总部、省/转运中心、网点、业务员、客户等每个环节，系统链接实',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 69,
#   'text': '现业务数据实时传导，价格、政策、结算全面数智化； ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 69,
#   'text': '■新业务新产品：以信息化、数字化、移动化驱动产品分层、供应链、国际、末端等快速拓展，支持新业务、新产品在',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 69,
#   'text': '运行、成本、时效、服务、客户体验等方面高效、便捷、可视。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 69, 'text': '（4）全新组织变革 ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 69,
#   'text': '针对2020年行业及公司在发展过程中暴露的痛点和短板，2021年要通过组织变革、人才聚拢、人尽其才、全面数智化等',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 69,
#   'text': '一揽子措施逐一解决掉，打造多个行业领先，全面追平优秀同行。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 69, 'text': '（5）持续降本增效 ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 69,
#   'text': '聚力“提质、降本、增效”，在全链路、全流程、全环节深入开展敏捷管理、柔性经营，达到优化经营、提升效率、降低',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 69,
#   'text': '成本、增厚利润目标；同时，精准赋能加盟商，通过接系统、支线协同、代集包等技术手段，帮助网点提高经营能力，提高',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 70,
#   'text': '其派送效率、降低派送成本等 。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 70, 'text': '（6）服务持续领先 ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 70,
#   'text': '公司将充分发挥科技领先优势和精细化管理能力，持续发力末端建设，进一步缩短包括揽件响应、交件管理、操作中转、',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 70,
#   'text': '干线运输、派件服务等服务时限，在全网全链路深入开展高水平的时间管理和服务提升，继续保持高水平的快递服务能力和',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 70,
#   'text': '可预期、可识别的快递服务时效，精心塑造好、维护好“韵达快递”品牌价值，为产品分层、客户分群、开发高端客户群提供',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 70, 'text': '业务能力条件和服务保障。 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 70,
#   'text': '2、推动“韵达+”生态圈向市场纵深发展  ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 70,
#   'text': '2021年，公司将持续构建“以快递为核心，融合周边产业、新业务、新业态协同发展”的多层次综合物流“生态圈”，以多',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 70,
#   'text': '样化的产品及服务打通上下游、拓展产业链、画大同心圆，深入经营韵达国际（跨境业务）、供应链、末端、冷链等业务板',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 70,
#   'text': '块，并以合理节奏不断将新业务、新产品向市场纵深推进。  ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 70,
#   'text': '■韵达国际方面：2021年，国际业务要抓住全球防疫的曙光机遇，紧紧依托我国“全球工厂”、“消费升级”和海外“巨大需',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 70,
#   'text': '求”三个有利条件，进一步加强进出口业务提升，落实全球大区/国家/重点城市目标拆分和对口，出口产品将更加丰富，仓、',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 70,
#   'text': '干、配、清关、客户平台、IT等基础服务能力要全面强化，使“韵达国际”的品牌力、影响力由点串线、由线成面。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 70,
#   'text': '■韵达供应链方面： 2021年，公司供应链业务将全面市场化、商业化、独立化经营发展；重点工作是：利用韵达快递',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 70,
#   'text': '的市场优势和客户优势，加大自有仓品牌建设，拓展云仓规模，通过仓管一体、仓干一体、仓配一体，深入做好与快递业务',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 70,
#   'text': 'VKA客户、KA客户、VIP客户等知名品牌客户的协同发展，在供应链、快递成本与时效、客户价值创造及服务体验等方面',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 70, 'text': '取得“多赢”的局面。 ', 'type': 'text', 'text_flag': 3},
#  {'page_number': 70,
#   'text': '■网络末端建设：2021年，公司纵向将大力发展快递网点、快递超市驿站、智能快递柜等，横向将持续开展社会性资源',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 70,
#   'text': '共配建设，进一步加强揽派能力建设和寄递便捷化建设，力促末端资源的用户数领先同行，以优异的末端资源优势和服务优',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 70,
#   'text': '势迎接日均3亿件包裹时代的到来。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 70,
#   'text': '■韵达冷链方面： 2020年第四季度，韵达冷链试水式亮相市场。2021年，韵达冷链业务将依托韵达既有网络优势，稳步',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 70,
#   'text': '投建冷链干线运输车辆，稳扎稳打、集腋成裘地塑造韵达冷链的服务能力和品牌，围绕7个城市集群、主要物流节点和主要',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 70,
#   'text': '区域市场，重点选取牛羊肉、大闸蟹、青笋、水果等富有特色的农牧福产品有序经营，由点成行、持续画圆、层层开拓，不',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 70,
#   'text': '断提高市场存在度，不断扩大经营品类，不断获得更多客户和消费者的信任与选择。 ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 70,
#   'text': '（三）公司可能面临的风险及应对措施 ',
#   'type': 'title',
#   'text_flag': -1},
#  {'page_number': 70, 'text': '1、市场环境风险  ', 'type': 'title', 'text_flag': -1},
#  {'page_number': 70,
#   'text': '经济波动风险：物流行业对国民经济发展具有重要的基础作用，同时也受到宏观经济形势的影响。近年来，我国宏观经',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 70,
#   'text': '济增速出现放缓，并处在经济结构的转型期，未来的发展仍然面临较为复杂的局面，宏观经济的波动可能对我国快递物流行',
#   'type': 'text',
#   'text_flag': 2},
#  {'page_number': 70,
#   'text': '业的整体发展产生一定影响。  ',
#   'type': 'text',
#   'text_flag': 3},
#  {'page_number': 70,
#   'text': '市场竞争风险：受新冠疫情影响，第一季度我国快递物流企业在道路通行、人员返岗、场地使用、包裹投递等方面受到',
#   'type': 'text',
#   'text_flag': 1},
#  {'page_number': 71,
#   'text': '一定程度的影响；受网络均衡性要求，部分快递企业可能存在部分地区、部分时段进行较激进式的业务需求回补，导致在部',
#   'type': 'text',
#   'text_flag': 2},
#  ...]
